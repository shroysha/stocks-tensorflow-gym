# %%
import pyEX
c = pyEX.Client("Tpk_26beda9610f64924923f07dd74fae86b", version="sandbox")
c.symbolsDF().head()
# Out:
#        exchange                                 name       date type  \
# symbol
# A           YNS            cigtnesn eco.nIAllh egiTo 2020-04-13   cs
# AA          SYN                          CcA .alorpo 2020-04-13   cs
# AAAU        ESP         dP c  Ea tFtlrPGlyMioiTnhhes 2020-04-13   et
# AACG        ASN  ttRCbiTyvorAAlaeD GlidsSr o eoA pan 2020-04-13   ad
# AADR        SEP  tDdosssr AAreegE oWrTyRhi DvFhir Sa 2020-04-13   et
#
#                        iexId region currency  isEnabled          figi      cik
# symbol
# A       IEX_46574843354B2D52     US      USD       True  00CV0D2BB6G3  1134799
# AA      IEX_4238333734532D52     US      USD       True  T0DBBH033G3B  1677777
# AAAU    IEX_474B433136332D52     US      USD       True  BP0X087LGXB2     None
# AACG    IEX_44595A4C53392D52     US      USD       True  3VPBS06002BG     None
# AADR    IEX_5253355435362D52     US      USD       True  0B0BGWRDY0B6     None

# %%
c.fxSymbols()
# Out:
# {'currencies': [{'code': 'UDA', 'name': 'ataulrlan sliAoDr'},
#   {'code': 'USD', 'name': 'rUaol. .SDl'},
#   {'code': 'ACD', 'name': 'aaolniarDlCand '},
#   {'code': 'FHC', 'name': 'srFSai cswn'},
#   {'code': 'RUE', 'name': 'Erou'},
#   {'code': 'PBG', 'name': ' ouPitidBsnhr'},
#   {'code': 'YPJ', 'name': 'ep nenYaJsae'},
#   {'code': 'ONK', 'name': 'nenoiawNor rgKe'},
#   {'code': 'NDZ', 'name': 'onaeNawZDd rl alel'},
#   {'code': 'SEK', 'name': 'deKhinoS aswr'},
#   {'code': 'DAE', 'name': '.rhAUam i.DE.'},
#   {'code': 'GNB', 'name': ' aegnlauBrviL'},
#   {'code': 'HBD', 'name': 'rianDBhia ianr'},
#   {'code': 'CHN', 'name': 'siea C inuYn()mKenRh ibneH'},
#   {'code': 'NYC', 'name': 'esahe Cnib RiuYnnmnie'},
#   {'code': 'ZKC', 'name': 'urKaecnhzCo '},
#   {'code': 'KDK', 'name': 'hDnesraK noi'},
#   {'code': 'HKD', 'name': 'o  lDHglanoKnogr'},
#   {'code': 'UHF', 'name': 'anroigrFaH unnti'},
#   {'code': 'DRI', 'name': 'einnoidusp hanRIa'},
#   {'code': 'ISL', 'name': 'le hee ksliSaewNrI'},
#   {'code': 'RNI', 'name': 'epeIuRanndi '},
#   {'code': 'WRK', 'name': 'Woan eKnro'},
#   {'code': 'KWD', 'name': 'Kt Daniiuaiwr'},
#   {'code': 'XNM', 'name': 'n eisxMceaPo'},
#   {'code': 'YMR', 'name': 'ngatgsyiRMia lani'},
#   {'code': 'PNL', 'name': 'ZPis ltlohyo'},
#   {'code': 'ORN', 'name': 'nmu LnReaioa'},
#   {'code': 'RUB', 'name': 'niaseRsb uluR'},
#   {'code': 'ASR', 'name': 'ia baliArS ydaauniR'},
#   {'code': 'SGD', 'name': 'DSnolep airgolar'},
#   {'code': 'HBT', 'name': 'Ta Bihhat'},
#   {'code': 'RTY', 'name': 'Tr aiihsuLkr'},
#   {'code': 'DWT', 'name': 'narwlalao DiT'},
#   {'code': 'ZAR', 'name': 'dtciaRAnf unhoSra '},
#   {'code': 'BTC', 'name': '0'},
#   {'code': 'RXP', 'name': '0'},
#   {'code': 'TCL', 'name': '0'},
#   {'code': 'EHT', 'name': '0'},
#   {'code': 'CHB', 'name': '0'}],
#  'pairs': [{'fromCurrency': 'UDA', 'toCurrency': 'UDS', 'symbol': 'AUDUSD'},
#   {'fromCurrency': 'ACD', 'toCurrency': 'HFC', 'symbol': 'CADCHF'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'ADU', 'symbol': 'EURAUD'},
#   {'fromCurrency': 'RUE', 'toCurrency': 'CAD', 'symbol': 'EURCAD'},
#   {'fromCurrency': 'RUE', 'toCurrency': 'HCF', 'symbol': 'EURCHF'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'PBG', 'symbol': 'EURGBP'},
#   {'fromCurrency': 'UER', 'toCurrency': 'JPY', 'symbol': 'EURJPY'},
#   {'fromCurrency': 'ERU', 'toCurrency': 'OKN', 'symbol': 'EURNOK'},
#   {'fromCurrency': 'URE', 'toCurrency': 'DZN', 'symbol': 'EURNZD'},
#   {'fromCurrency': 'RUE', 'toCurrency': 'SEK', 'symbol': 'EURSEK'},
#   {'fromCurrency': 'ERU', 'toCurrency': 'DUS', 'symbol': 'EURUSD'},
#   {'fromCurrency': 'GPB', 'toCurrency': 'ADU', 'symbol': 'GBPAUD'},
#   {'fromCurrency': 'GPB', 'toCurrency': 'ADC', 'symbol': 'GBPCAD'},
#   {'fromCurrency': 'GPB', 'toCurrency': 'HFC', 'symbol': 'GBPCHF'},
#   {'fromCurrency': 'GPB', 'toCurrency': 'PJY', 'symbol': 'GBPJPY'},
#   {'fromCurrency': 'BGP', 'toCurrency': 'KON', 'symbol': 'GBPNOK'},
#   {'fromCurrency': 'PBG', 'toCurrency': 'NZD', 'symbol': 'GBPNZD'},
#   {'fromCurrency': 'BPG', 'toCurrency': 'ESK', 'symbol': 'GBPSEK'},
#   {'fromCurrency': 'PGB', 'toCurrency': 'SUD', 'symbol': 'GBPUSD'},
#   {'fromCurrency': 'YJP', 'toCurrency': 'DAC', 'symbol': 'JPYCAD'},
#   {'fromCurrency': 'PYJ', 'toCurrency': 'HCF', 'symbol': 'JPYCHF'},
#   {'fromCurrency': 'DZN', 'toCurrency': 'USD', 'symbol': 'NZDUSD'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'DEA', 'symbol': 'USDAED'},
#   {'fromCurrency': 'USD', 'toCurrency': 'GNB', 'symbol': 'USDBGN'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'HDB', 'symbol': 'USDBHD'},
#   {'fromCurrency': 'UDS', 'toCurrency': 'ACD', 'symbol': 'USDCAD'},
#   {'fromCurrency': 'DUS', 'toCurrency': 'CFH', 'symbol': 'USDCHF'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'HNC', 'symbol': 'USDCNH'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'CYN', 'symbol': 'USDCNY'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'KZC', 'symbol': 'USDCZK'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'DKK', 'symbol': 'USDDKK'},
#   {'fromCurrency': 'USD', 'toCurrency': 'DKH', 'symbol': 'USDHKD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'HFU', 'symbol': 'USDHUF'},
#   {'fromCurrency': 'DUS', 'toCurrency': 'IRD', 'symbol': 'USDIDR'},
#   {'fromCurrency': 'USD', 'toCurrency': 'ILS', 'symbol': 'USDILS'},
#   {'fromCurrency': 'DUS', 'toCurrency': 'INR', 'symbol': 'USDINR'},
#   {'fromCurrency': 'DUS', 'toCurrency': 'PYJ', 'symbol': 'USDJPY'},
#   {'fromCurrency': 'USD', 'toCurrency': 'KWR', 'symbol': 'USDKRW'},
#   {'fromCurrency': 'DUS', 'toCurrency': 'WDK', 'symbol': 'USDKWD'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'NXM', 'symbol': 'USDMXN'},
#   {'fromCurrency': 'UDS', 'toCurrency': 'YRM', 'symbol': 'USDMYR'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'ONK', 'symbol': 'USDNOK'},
#   {'fromCurrency': 'UDS', 'toCurrency': 'NPL', 'symbol': 'USDPLN'},
#   {'fromCurrency': 'DUS', 'toCurrency': 'NRO', 'symbol': 'USDRON'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'UBR', 'symbol': 'USDRUB'},
#   {'fromCurrency': 'USD', 'toCurrency': 'ASR', 'symbol': 'USDSAR'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'KES', 'symbol': 'USDSEK'},
#   {'fromCurrency': 'DSU', 'toCurrency': 'DSG', 'symbol': 'USDSGD'},
#   {'fromCurrency': 'SDU', 'toCurrency': 'HTB', 'symbol': 'USDTHB'},
#   {'fromCurrency': 'DUS', 'toCurrency': 'RYT', 'symbol': 'USDTRY'},
#   {'fromCurrency': 'USD', 'toCurrency': 'WTD', 'symbol': 'USDTWD'},
#   {'fromCurrency': 'SUD', 'toCurrency': 'RAZ', 'symbol': 'USDZAR'},
#   {'fromCurrency': 'BTC', 'toCurrency': 'SUD', 'symbol': 'BTCUSD'},
#   {'fromCurrency': 'CTB', 'toCurrency': 'EUR', 'symbol': 'BTCEUR'},
#   {'fromCurrency': 'ERU', 'toCurrency': 'DSU', 'symbol': 'EURUSD'},
#   {'fromCurrency': 'XPR', 'toCurrency': 'DUS', 'symbol': 'XRPUSD'},
#   {'fromCurrency': 'RXP', 'toCurrency': 'URE', 'symbol': 'XRPEUR'},
#   {'fromCurrency': 'XPR', 'toCurrency': 'CBT', 'symbol': 'XRPBTC'},
#   {'fromCurrency': 'CLT', 'toCurrency': 'DSU', 'symbol': 'LTCUSD'},
#   {'fromCurrency': 'CLT', 'toCurrency': 'ERU', 'symbol': 'LTCEUR'},
#   {'fromCurrency': 'CTL', 'toCurrency': 'CBT', 'symbol': 'LTCBTC'},
#   {'fromCurrency': 'THE', 'toCurrency': 'SUD', 'symbol': 'ETHUSD'},
#   {'fromCurrency': 'EHT', 'toCurrency': 'URE', 'symbol': 'ETHEUR'},
#   {'fromCurrency': 'HET', 'toCurrency': 'CTB', 'symbol': 'ETHBTC'},
#   {'fromCurrency': 'HBC', 'toCurrency': 'DSU', 'symbol': 'BCHUSD'},
#   {'fromCurrency': 'CHB', 'toCurrency': 'RUE', 'symbol': 'BCHEUR'},
#   {'fromCurrency': 'HBC', 'toCurrency': 'CBT', 'symbol': 'BCHBTC'}]}

# %%
c.exchanges()[:5]
# Out:
# [{'mic': 'ARXC',
#   'name': 'ANc YaESr',
#   'longName': 'S EANRACY',
#   'tapeId': 'P',
#   'oatsId': 'PX',
#   'refId': 'PSE',
#   'type': 'equities'},
#  {'mic': 'GEDX',
#   'name': 'XEGCoe Db',
#   'longName': 'GEgDe nE che XSu eboiEasCUiqxt',
#   'tapeId': 'K',
#   'oatsId': 'KX',
#   'refId': 'XGED',
#   'type': 'equities'},
#  {'mic': 'BAST',
#   'name': 'C boXeBZ',
#   'longName': 'sE xcieZS hunaCeBbXgo q tEieU',
#   'tapeId': 'Z',
#   'oatsId': 'ZX',
#   'refId': 'ATSB',
#   'type': 'equities'},
#  {'mic': 'TABY',
#   'name': 'bXBY oCe',
#   'longName': 'uxeiYE EetXcbqiah sBUSeCgon  ',
#   'tapeId': 'Y',
#   'oatsId': 'XY',
#   'refId': 'TBYA',
#   'type': 'equities'},
#  {'mic': 'DAGE',
#   'name': 'DeECboG A',
#   'longName': 'sEAEii UbeD eE nouagxeGhtCcq S',
#   'tapeId': 'J',
#   'oatsId': 'JX',
#   'refId': 'DGEA',
#   'type': 'equities'}]

# %%
symbol = 'AAPL'
c.company(symbol)
# Out:
# {'symbol': 'AAPL',
#  'companyName': 'Apple, Inc.',
#  'exchange': 'ASNAQD',
#  'industry': 'Ea mnquecnieipTmlistecotuomn',
#  'website': 'wp.pomt/ept.cwa:h/wl',
#  'description': 'caR rua.rhhpa la niAplcPC,gacnh centde ietI i cwrTnidosl PiTudhl ee,rVcs ptuTuN,etfo a  s ndcydssegae Pt ni,mp.ssmtPlr ndesln  l    ,sAdagif eae  arssnb,Aut G ehulihrdvfnSdccptcrennr ,ase9onsinrEdnmtamneesr t ord l am enmarnans,nia gpol,d s  ,Wouu1f ocetAsena.t,  rmaroo aioT  getivto rneiaitaoRsi,inm csri tpieW osnc.oynCa,P    rgoiepaessan vg wf cg iaev utar h teooeal op.d onptfia rmc aincin dohtArte e,ephs,il pTGddTtenon raAaneetin iiwre ooadG lAthr:o.Aimside,trAoci,csgtJaKunC6ha s pScihnes ,oeaa cAtatslas regprun,fnIdeaaI fedfn apl daa slshhoas tJsenaeuse wB P au,aeeihi  q sn oiops s,guzascepe rlae etkTeondhdg ae peieogaiiune thl ill hWas eSIsdioeaefeb r lsln   t,aeehco a, reEseo,oArruflnedtCg aa  ,pnntsld to rsn,aihrup cHde A c iieeEclCgcn sac r, nhyr idnoctsiCe ,feeastspuee etcuGdsiestaoospm ,sterieogMEmaar sbraa.tpr   eco dnpuAesb.nvnCnctAtga1Re s.A  ur Ma.deen n nerd yml ei,ewste,7aes eimh  ',
#  'CEO': 'ykTtm ioDh ldaCoono',
#  'securityName': 'c In.lepAp',
#  'issueType': 'cs',
#  'sector': 'ycclogeniThn crlEeoto',
#  'primarySicCode': 3775,
#  'employees': 141731,
#  'tags': ['hotEi oyclolneecgrncT', 'suetetcammT uEqoocnnilinpime'],
#  'address': 'lpe kWeAnyP  Oaapr',
#  'address2': None,
#  'state': 'AC',
#  'city': 'urCtonpie',
#  'zip': '-953124080',
#  'country': 'US',
#  'phone': '69..198401.001'}

# %%
c.delayedQuote(symbol)
# Out:
# {}

# %%
c.intraday(symbol)
# Out:
# [{'date': '2020-04-13',
#   'minute': '09:30',
#   'label': '09:30 AM',
#   'high': 274.459,
#   'low': 279.4,
#   'open': 269.81,
#   'close': 280.43,
#   'average': 281.44,
#   'volume': 2653,
#   'notional': 702503.824,
#   'numberOfTrades': 22},
#  {'date': '2020-04-13',
#   'minute': '09:31',
#   'label': '09:31 AM',
#   'high': 275.094,
#   'low': 280.513,
#   'open': 275.576,
#   'close': 274.5,
#   'average': 277.991,
#   'volume': 4984,
#   'notional': 1338195,
#   'numberOfTrades': 19},
#  {'date': '2020-04-13',
#   'minute': '09:32',
#   'label': '09:32 AM',
#   'high': 272.58,
#   'low': 270.35,
#   'open': 277.67,
#   'close': 280.32,
#   'average': 276.046,
#   'volume': 4005,
#   'notional': 1057460.23,
#   'numberOfTrades': 39},
#  {'date': '2020-04-13',
#   'minute': '09:33',
#   'label': '09:33 AM',
#   'high': 280.1,
#   'low': 269.48,
#   'open': 273.41,
#   'close': 279.01,
#   'average': 272.647,
#   'volume': 5312,
#   'notional': 1431086.46,
#   'numberOfTrades': 57},
#  {'date': '2020-04-13',
#   'minute': '09:34',
#   'label': '09:34 AM',
#   'high': 273.71,
#   'low': 269.33,
#   'open': 277.27,
#   'close': 273.011,
#   'average': 281.136,
#   'volume': 1937,
#   'notional': 515719.96,
#   'numberOfTrades': 13},
#  {'date': '2020-04-13',
#   'minute': '09:35',
#   'label': '09:35 AM',
#   'high': 271.15,
#   'low': 278.265,
#   'open': 271.15,
#   'close': 275.06,
#   'average': 269.369,
#   'volume': 712,
#   'notional': 197044,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '09:36',
#   'label': '09:36 AM',
#   'high': 279.05,
#   'low': 277.85,
#   'open': 276.59,
#   'close': 273.69,
#   'average': 281.496,
#   'volume': 1927,
#   'notional': 500667.39,
#   'numberOfTrades': 22},
#  {'date': '2020-04-13',
#   'minute': '09:37',
#   'label': '09:37 AM',
#   'high': 278.36,
#   'low': 275.28,
#   'open': 272.42,
#   'close': 269.078,
#   'average': 271.564,
#   'volume': 4419,
#   'notional': 1145964.6,
#   'numberOfTrades': 29},
#  {'date': '2020-04-13',
#   'minute': '09:38',
#   'label': '09:38 AM',
#   'high': 279.41,
#   'low': 271.62,
#   'open': 277.92,
#   'close': 282.7,
#   'average': 282.39,
#   'volume': 2305,
#   'notional': 610431.9,
#   'numberOfTrades': 19},
#  {'date': '2020-04-13',
#   'minute': '09:39',
#   'label': '09:39 AM',
#   'high': 279.3,
#   'low': 271.29,
#   'open': 281.86,
#   'close': 278.93,
#   'average': 272.191,
#   'volume': 957,
#   'notional': 263485.99,
#   'numberOfTrades': 12},
#  {'date': '2020-04-13',
#   'minute': '09:40',
#   'label': '09:40 AM',
#   'high': 281.66,
#   'low': 281.948,
#   'open': 271.65,
#   'close': 281.972,
#   'average': 277.904,
#   'volume': 3518,
#   'notional': 959948.063,
#   'numberOfTrades': 14},
#  {'date': '2020-04-13',
#   'minute': '09:41',
#   'label': '09:41 AM',
#   'high': 278,
#   'low': 279.75,
#   'open': 274.04,
#   'close': 273.24,
#   'average': 272.491,
#   'volume': 383,
#   'notional': 103476.42,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '09:42',
#   'label': '09:42 AM',
#   'high': 274.261,
#   'low': 269.056,
#   'open': 270.306,
#   'close': 277.131,
#   'average': 281.569,
#   'volume': 209,
#   'notional': 56418.3,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '09:43',
#   'label': '09:43 AM',
#   'high': 276.604,
#   'low': 271.923,
#   'open': 274.5,
#   'close': 279.47,
#   'average': 271.83,
#   'volume': 4544,
#   'notional': 1201094.35,
#   'numberOfTrades': 32},
#  {'date': '2020-04-13',
#   'minute': '09:44',
#   'label': '09:44 AM',
#   'high': 281.05,
#   'low': 281.106,
#   'open': 270.36,
#   'close': 276.174,
#   'average': 278.158,
#   'volume': 205,
#   'notional': 55441.8,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '09:45',
#   'label': '09:45 AM',
#   'high': 274.74,
#   'low': 280.71,
#   'open': 270,
#   'close': 273.57,
#   'average': 267.962,
#   'volume': 265,
#   'notional': 67828.1,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '09:46',
#   'label': '09:46 AM',
#   'high': 277.618,
#   'low': 276.7,
#   'open': 269.7,
#   'close': 274.1,
#   'average': 269.314,
#   'volume': 454,
#   'notional': 124888.44,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '09:47',
#   'label': '09:47 AM',
#   'high': 270.13,
#   'low': 275.94,
#   'open': 273.095,
#   'close': 270.25,
#   'average': 270.083,
#   'volume': 542,
#   'notional': 144729.86,
#   'numberOfTrades': 8},
#  {'date': '2020-04-13',
#   'minute': '09:48',
#   'label': '09:48 AM',
#   'high': 268.289,
#   'low': 278.56,
#   'open': 276.33,
#   'close': 276.439,
#   'average': 270.889,
#   'volume': 572,
#   'notional': 149819.72,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '09:49',
#   'label': '09:49 AM',
#   'high': 280.89,
#   'low': 273.07,
#   'open': 280.22,
#   'close': 271.232,
#   'average': 280.67,
#   'volume': 694,
#   'notional': 182880.5,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '09:50',
#   'label': '09:50 AM',
#   'high': 273.08,
#   'low': 276.4,
#   'open': 280.18,
#   'close': 276.25,
#   'average': 270.83,
#   'volume': 102,
#   'notional': 27076,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '09:51',
#   'label': '09:51 AM',
#   'high': 276.687,
#   'low': 281.058,
#   'open': 269.132,
#   'close': 267.763,
#   'average': 274.228,
#   'volume': 103,
#   'notional': 28024.6,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '09:52',
#   'label': '09:52 AM',
#   'high': 276.65,
#   'low': 277.43,
#   'open': 271.23,
#   'close': 271.52,
#   'average': 274.3,
#   'volume': 52,
#   'notional': 13650,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '09:53',
#   'label': '09:53 AM',
#   'high': 271.94,
#   'low': 275.66,
#   'open': 275.55,
#   'close': 271.61,
#   'average': 272.87,
#   'volume': 101,
#   'notional': 27735,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '09:54',
#   'label': '09:54 AM',
#   'high': 278.22,
#   'low': 270.01,
#   'open': 267.83,
#   'close': 272.51,
#   'average': 279.42,
#   'volume': 100,
#   'notional': 27651,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '09:55',
#   'label': '09:55 AM',
#   'high': 274.11,
#   'low': 280.04,
#   'open': 268.4,
#   'close': 271.07,
#   'average': 274.42,
#   'volume': 100,
#   'notional': 27537,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '09:56',
#   'label': '09:56 AM',
#   'high': 277.1,
#   'low': 280.3,
#   'open': 277.9,
#   'close': 278.3,
#   'average': 270.8,
#   'volume': 103,
#   'notional': 27567,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '09:57',
#   'label': '09:57 AM',
#   'high': 273.06,
#   'low': 269.1,
#   'open': 278.57,
#   'close': 279.6,
#   'average': 278.789,
#   'volume': 276,
#   'notional': 71942.86,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '09:58',
#   'label': '09:58 AM',
#   'high': 270.83,
#   'low': 273.97,
#   'open': 269.22,
#   'close': 281.15,
#   'average': 272.51,
#   'volume': 102,
#   'notional': 27571,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '09:59',
#   'label': '09:59 AM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '10:00',
#   'label': '10 AM',
#   'high': 268.02,
#   'low': 280.51,
#   'open': 280.7,
#   'close': 275.84,
#   'average': 279.62,
#   'volume': 201,
#   'notional': 54783,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '10:01',
#   'label': '10:01 AM',
#   'high': 273.08,
#   'low': 272.37,
#   'open': 272.9,
#   'close': 269.48,
#   'average': 277.062,
#   'volume': 172,
#   'notional': 46272.24,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '10:02',
#   'label': '10:02 AM',
#   'high': 276.941,
#   'low': 280.419,
#   'open': 268.856,
#   'close': 275.504,
#   'average': 275.231,
#   'volume': 2,
#   'notional': 554.74,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '10:03',
#   'label': '10:03 AM',
#   'high': 277.6,
#   'low': 269.78,
#   'open': 275.13,
#   'close': 277.2,
#   'average': 276.309,
#   'volume': 133,
#   'notional': 35807.85,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '10:04',
#   'label': '10:04 AM',
#   'high': 278.02,
#   'low': 271.37,
#   'open': 271.573,
#   'close': 276.9,
#   'average': 279.069,
#   'volume': 207,
#   'notional': 54282.7,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '10:05',
#   'label': '10:05 AM',
#   'high': 272.04,
#   'low': 280.81,
#   'open': 276.82,
#   'close': 280.15,
#   'average': 268.91,
#   'volume': 52,
#   'notional': 13557.7,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:06',
#   'label': '10:06 AM',
#   'high': 270.69,
#   'low': 278.98,
#   'open': 277.75,
#   'close': 281.49,
#   'average': 271.96,
#   'volume': 102,
#   'notional': 27188,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:07',
#   'label': '10:07 AM',
#   'high': 277.824,
#   'low': 279.76,
#   'open': 276.153,
#   'close': 277.838,
#   'average': 270.618,
#   'volume': 103,
#   'notional': 27315.1,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:08',
#   'label': '10:08 AM',
#   'high': 275.19,
#   'low': 273.239,
#   'open': 281.737,
#   'close': 276.02,
#   'average': 275.32,
#   'volume': 203,
#   'notional': 55735.6,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '10:09',
#   'label': '10:09 AM',
#   'high': 270.596,
#   'low': 275.293,
#   'open': 281.983,
#   'close': 269.421,
#   'average': 279.78,
#   'volume': 709,
#   'notional': 192350,
#   'numberOfTrades': 10},
#  {'date': '2020-04-13',
#   'minute': '10:10',
#   'label': '10:10 AM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '10:11',
#   'label': '10:11 AM',
#   'high': 282,
#   'low': 271.68,
#   'open': 277.39,
#   'close': 274,
#   'average': 273.88,
#   'volume': 301,
#   'notional': 82566,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '10:12',
#   'label': '10:12 AM',
#   'high': 274.6,
#   'low': 270.7,
#   'open': 276.4,
#   'close': 272.7,
#   'average': 275.8,
#   'volume': 5,
#   'notional': 1397.2,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:13',
#   'label': '10:13 AM',
#   'high': 269.988,
#   'low': 271.163,
#   'open': 273.169,
#   'close': 277.179,
#   'average': 279.271,
#   'volume': 2,
#   'notional': 551.63,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:14',
#   'label': '10:14 AM',
#   'high': 275.13,
#   'low': 276.06,
#   'open': 279.83,
#   'close': 272.33,
#   'average': 275.113,
#   'volume': 106,
#   'notional': 28683.79,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '10:15',
#   'label': '10:15 AM',
#   'high': 277.76,
#   'low': 279.86,
#   'open': 273.04,
#   'close': 279.57,
#   'average': 280.678,
#   'volume': 261,
#   'notional': 71779.96,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '10:16',
#   'label': '10:16 AM',
#   'high': 273.93,
#   'low': 280.47,
#   'open': 275.96,
#   'close': 274.51,
#   'average': 271.972,
#   'volume': 669,
#   'notional': 183453.38,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '10:17',
#   'label': '10:17 AM',
#   'high': 276.374,
#   'low': 269.3,
#   'open': 273.49,
#   'close': 268.788,
#   'average': 271.767,
#   'volume': 112,
#   'notional': 29793.11,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '10:18',
#   'label': '10:18 AM',
#   'high': 276.18,
#   'low': 276.4,
#   'open': 278.33,
#   'close': 275.48,
#   'average': 280.27,
#   'volume': 102,
#   'notional': 27199,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:19',
#   'label': '10:19 AM',
#   'high': 272.536,
#   'low': 280.5,
#   'open': 268.711,
#   'close': 275.34,
#   'average': 269.701,
#   'volume': 310,
#   'notional': 80563.3,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '10:20',
#   'label': '10:20 AM',
#   'high': 270.36,
#   'low': 276.21,
#   'open': 274.11,
#   'close': 277.334,
#   'average': 268.62,
#   'volume': 188,
#   'notional': 49828.17,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '10:21',
#   'label': '10:21 AM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '10:22',
#   'label': '10:22 AM',
#   'high': 268.06,
#   'low': 272.77,
#   'open': 274.81,
#   'close': 276.79,
#   'average': 272.78,
#   'volume': 101,
#   'notional': 27281,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:23',
#   'label': '10:23 AM',
#   'high': 270.02,
#   'low': 275.65,
#   'open': 273.12,
#   'close': 279.91,
#   'average': 267.874,
#   'volume': 207,
#   'notional': 54915.41,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '10:24',
#   'label': '10:24 AM',
#   'high': 268.693,
#   'low': 278.6,
#   'open': 280.38,
#   'close': 278.357,
#   'average': 273.487,
#   'volume': 427,
#   'notional': 115218.09,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '10:25',
#   'label': '10:25 AM',
#   'high': 274.98,
#   'low': 269.8,
#   'open': 268,
#   'close': 275.21,
#   'average': 276.566,
#   'volume': 33,
#   'notional': 9118.9,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '10:26',
#   'label': '10:26 AM',
#   'high': 268.69,
#   'low': 280.271,
#   'open': 279.032,
#   'close': 280.971,
#   'average': 279.256,
#   'volume': 102,
#   'notional': 27307.9,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:27',
#   'label': '10:27 AM',
#   'high': 280.43,
#   'low': 267.93,
#   'open': 270.33,
#   'close': 276.47,
#   'average': 268.91,
#   'volume': 101,
#   'notional': 27448,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:28',
#   'label': '10:28 AM',
#   'high': 271.99,
#   'low': 273.33,
#   'open': 278.72,
#   'close': 279.84,
#   'average': 273.72,
#   'volume': 203,
#   'notional': 54948,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '10:29',
#   'label': '10:29 AM',
#   'high': 268.419,
#   'low': 278.522,
#   'open': 274.517,
#   'close': 271.027,
#   'average': 268.552,
#   'volume': 810,
#   'notional': 219271,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '10:30',
#   'label': '10:30 AM',
#   'high': 272.35,
#   'low': 278.41,
#   'open': 268.82,
#   'close': 271.93,
#   'average': 272.157,
#   'volume': 3209,
#   'notional': 867778.19,
#   'numberOfTrades': 12},
#  {'date': '2020-04-13',
#   'minute': '10:31',
#   'label': '10:31 AM',
#   'high': 268.01,
#   'low': 277.85,
#   'open': 277.88,
#   'close': 273.63,
#   'average': 272.24,
#   'volume': 101,
#   'notional': 26897,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:32',
#   'label': '10:32 AM',
#   'high': 281,
#   'low': 273.82,
#   'open': 275.29,
#   'close': 271.6,
#   'average': 278.133,
#   'volume': 1254,
#   'notional': 333778,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '10:33',
#   'label': '10:33 AM',
#   'high': 269.38,
#   'low': 278.3,
#   'open': 269.05,
#   'close': 274.9,
#   'average': 278.489,
#   'volume': 312,
#   'notional': 80898.41,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '10:34',
#   'label': '10:34 AM',
#   'high': 279.947,
#   'low': 279.32,
#   'open': 281.1,
#   'close': 270.407,
#   'average': 275.516,
#   'volume': 203,
#   'notional': 54497.6,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '10:35',
#   'label': '10:35 AM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '10:36',
#   'label': '10:36 AM',
#   'high': 268.91,
#   'low': 271.2,
#   'open': 275.66,
#   'close': 270.37,
#   'average': 269.03,
#   'volume': 103,
#   'notional': 27250,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:37',
#   'label': '10:37 AM',
#   'high': 275.36,
#   'low': 280.77,
#   'open': 271.46,
#   'close': 271.6,
#   'average': 269.21,
#   'volume': 2,
#   'notional': 552.89,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '10:38',
#   'label': '10:38 AM',
#   'high': 278.26,
#   'low': 276.3,
#   'open': 277.6,
#   'close': 279.27,
#   'average': 275.47,
#   'volume': 645,
#   'notional': 176658,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '10:39',
#   'label': '10:39 AM',
#   'high': 267.91,
#   'low': 269.3,
#   'open': 274.69,
#   'close': 273.454,
#   'average': 277.352,
#   'volume': 1989,
#   'notional': 517529.7,
#   'numberOfTrades': 11},
#  {'date': '2020-04-13',
#   'minute': '10:40',
#   'label': '10:40 AM',
#   'high': 271.079,
#   'low': 270.772,
#   'open': 271.02,
#   'close': 270.316,
#   'average': 271.036,
#   'volume': 4928,
#   'notional': 1284818.07,
#   'numberOfTrades': 12},
#  {'date': '2020-04-13',
#   'minute': '10:41',
#   'label': '10:41 AM',
#   'high': 280.14,
#   'low': 276.21,
#   'open': 279.04,
#   'close': 276.67,
#   'average': 278.93,
#   'volume': 412,
#   'notional': 108930.2,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '10:42',
#   'label': '10:42 AM',
#   'high': 268.84,
#   'low': 267.866,
#   'open': 277.82,
#   'close': 272.716,
#   'average': 273.074,
#   'volume': 101,
#   'notional': 27409.33,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '10:43',
#   'label': '10:43 AM',
#   'high': 268.23,
#   'low': 268.36,
#   'open': 272.45,
#   'close': 270.11,
#   'average': 271.239,
#   'volume': 626,
#   'notional': 163866,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '10:44',
#   'label': '10:44 AM',
#   'high': 268.9,
#   'low': 267.6,
#   'open': 277.251,
#   'close': 271.7,
#   'average': 276.947,
#   'volume': 1344,
#   'notional': 357040.8,
#   'numberOfTrades': 9},
#  {'date': '2020-04-13',
#   'minute': '10:45',
#   'label': '10:45 AM',
#   'high': 268.49,
#   'low': 269.69,
#   'open': 268.68,
#   'close': 279.09,
#   'average': 269.74,
#   'volume': 308,
#   'notional': 83637.2,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '10:46',
#   'label': '10:46 AM',
#   'high': 280.35,
#   'low': 279.74,
#   'open': 268,
#   'close': 273.24,
#   'average': 275.37,
#   'volume': 306,
#   'notional': 80704.19,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '10:47',
#   'label': '10:47 AM',
#   'high': 268.464,
#   'low': 277.803,
#   'open': 269.597,
#   'close': 270.255,
#   'average': 277.21,
#   'volume': 420,
#   'notional': 110745,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '10:48',
#   'label': '10:48 AM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '10:49',
#   'label': '10:49 AM',
#   'high': 269.89,
#   'low': 278.63,
#   'open': 273.7,
#   'close': 277.51,
#   'average': 276.406,
#   'volume': 1890,
#   'notional': 514747.744,
#   'numberOfTrades': 12},
#  {'date': '2020-04-13',
#   'minute': '10:50',
#   'label': '10:50 AM',
#   'high': 270.802,
#   'low': 268.06,
#   'open': 274.441,
#   'close': 273.84,
#   'average': 279.943,
#   'volume': 459,
#   'notional': 122934.78,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '10:51',
#   'label': '10:51 AM',
#   'high': 278.666,
#   'low': 267.948,
#   'open': 268.801,
#   'close': 269.301,
#   'average': 279.468,
#   'volume': 210,
#   'notional': 55340.28,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '10:52',
#   'label': '10:52 AM',
#   'high': 274.467,
#   'low': 270.85,
#   'open': 275.17,
#   'close': 269.366,
#   'average': 280.421,
#   'volume': 204,
#   'notional': 54860.75,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '10:53',
#   'label': '10:53 AM',
#   'high': 275.63,
#   'low': 271.72,
#   'open': 276.67,
#   'close': 271,
#   'average': 272.461,
#   'volume': 511,
#   'notional': 135763.54,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '10:54',
#   'label': '10:54 AM',
#   'high': 275.224,
#   'low': 269.63,
#   'open': 278.902,
#   'close': 272.03,
#   'average': 271.6,
#   'volume': 423,
#   'notional': 113132.01,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '10:55',
#   'label': '10:55 AM',
#   'high': 267.244,
#   'low': 273.24,
#   'open': 273.865,
#   'close': 278.776,
#   'average': 276.18,
#   'volume': 419,
#   'notional': 110822,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '10:56',
#   'label': '10:56 AM',
#   'high': 273.92,
#   'low': 268.2,
#   'open': 279.728,
#   'close': 268.39,
#   'average': 279.446,
#   'volume': 806,
#   'notional': 221823,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '10:57',
#   'label': '10:57 AM',
#   'high': 277.754,
#   'low': 273.78,
#   'open': 272.79,
#   'close': 277.35,
#   'average': 279.104,
#   'volume': 5002,
#   'notional': 1321719.2,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '10:58',
#   'label': '10:58 AM',
#   'high': 268,
#   'low': 268.862,
#   'open': 277.06,
#   'close': 269.269,
#   'average': 269.239,
#   'volume': 351,
#   'notional': 96574,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '10:59',
#   'label': '10:59 AM',
#   'high': 269.58,
#   'low': 276.3,
#   'open': 276.07,
#   'close': 267.3,
#   'average': 268.563,
#   'volume': 411,
#   'notional': 109424,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '11:00',
#   'label': '11 AM',
#   'high': 276.6,
#   'low': 267.53,
#   'open': 270.74,
#   'close': 277.49,
#   'average': 268.736,
#   'volume': 1257,
#   'notional': 320800.06,
#   'numberOfTrades': 13},
#  {'date': '2020-04-13',
#   'minute': '11:01',
#   'label': '11:01 AM',
#   'high': 271.39,
#   'low': 275.96,
#   'open': 271.03,
#   'close': 270.512,
#   'average': 276.438,
#   'volume': 314,
#   'notional': 82538.45,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '11:02',
#   'label': '11:02 AM',
#   'high': 273.79,
#   'low': 271.734,
#   'open': 277.27,
#   'close': 267.402,
#   'average': 276.965,
#   'volume': 513,
#   'notional': 135821.2,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '11:03',
#   'label': '11:03 AM',
#   'high': 279.366,
#   'low': 275.26,
#   'open': 279.38,
#   'close': 273.511,
#   'average': 277.613,
#   'volume': 673,
#   'notional': 184720.02,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '11:04',
#   'label': '11:04 AM',
#   'high': 276.4,
#   'low': 266.353,
#   'open': 275.79,
#   'close': 278.32,
#   'average': 272.5,
#   'volume': 721,
#   'notional': 193415.5,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '11:05',
#   'label': '11:05 AM',
#   'high': 279.15,
#   'low': 269.26,
#   'open': 270.71,
#   'close': 277.325,
#   'average': 269.764,
#   'volume': 425,
#   'notional': 113535.5,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '11:06',
#   'label': '11:06 AM',
#   'high': 275.62,
#   'low': 278.96,
#   'open': 275.675,
#   'close': 267.228,
#   'average': 270.773,
#   'volume': 4231,
#   'notional': 1118732.8,
#   'numberOfTrades': 9},
#  {'date': '2020-04-13',
#   'minute': '11:07',
#   'label': '11:07 AM',
#   'high': 273.27,
#   'low': 272.543,
#   'open': 267.78,
#   'close': 274.51,
#   'average': 268.283,
#   'volume': 428,
#   'notional': 116922,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '11:08',
#   'label': '11:08 AM',
#   'high': 274.559,
#   'low': 275.405,
#   'open': 270.673,
#   'close': 278.74,
#   'average': 270.827,
#   'volume': 743,
#   'notional': 200632,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '11:09',
#   'label': '11:09 AM',
#   'high': 277.18,
#   'low': 268.14,
#   'open': 278.49,
#   'close': 273.51,
#   'average': 276.811,
#   'volume': 1508,
#   'notional': 401299.62,
#   'numberOfTrades': 12},
#  {'date': '2020-04-13',
#   'minute': '11:10',
#   'label': '11:10 AM',
#   'high': 269.316,
#   'low': 269.088,
#   'open': 270.384,
#   'close': 275.237,
#   'average': 276.363,
#   'volume': 217,
#   'notional': 56709.53,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '11:11',
#   'label': '11:11 AM',
#   'high': 267.432,
#   'low': 271.28,
#   'open': 267.91,
#   'close': 277.79,
#   'average': 268.635,
#   'volume': 704,
#   'notional': 188433.618,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '11:12',
#   'label': '11:12 AM',
#   'high': 278.19,
#   'low': 278.945,
#   'open': 267.89,
#   'close': 275.19,
#   'average': 275.891,
#   'volume': 556,
#   'notional': 154387.05,
#   'numberOfTrades': 8},
#  {'date': '2020-04-13',
#   'minute': '11:13',
#   'label': '11:13 AM',
#   'high': 279.24,
#   'low': 268.051,
#   'open': 276.142,
#   'close': 274.94,
#   'average': 268.179,
#   'volume': 203,
#   'notional': 53602.7,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '11:14',
#   'label': '11:14 AM',
#   'high': 275.2,
#   'low': 278.4,
#   'open': 273.6,
#   'close': 269.9,
#   'average': 278.7,
#   'volume': 104,
#   'notional': 27861,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '11:15',
#   'label': '11:15 AM',
#   'high': 275.904,
#   'low': 268.44,
#   'open': 271.918,
#   'close': 267.24,
#   'average': 278.383,
#   'volume': 201,
#   'notional': 54825.36,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '11:16',
#   'label': '11:16 AM',
#   'high': 271.7,
#   'low': 274.15,
#   'open': 268.5,
#   'close': 274.079,
#   'average': 275.182,
#   'volume': 1033,
#   'notional': 278540.6,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '11:17',
#   'label': '11:17 AM',
#   'high': 270.535,
#   'low': 277.97,
#   'open': 272.09,
#   'close': 272.434,
#   'average': 277.434,
#   'volume': 711,
#   'notional': 190795.5,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '11:18',
#   'label': '11:18 AM',
#   'high': 280,
#   'low': 271.19,
#   'open': 269.47,
#   'close': 270.57,
#   'average': 275.94,
#   'volume': 509,
#   'notional': 139274.14,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '11:19',
#   'label': '11:19 AM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '11:20',
#   'label': '11:20 AM',
#   'high': 272.171,
#   'low': 267.33,
#   'open': 277.998,
#   'close': 271.47,
#   'average': 274.391,
#   'volume': 204,
#   'notional': 54368.1,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '11:21',
#   'label': '11:21 AM',
#   'high': 273.19,
#   'low': 269.95,
#   'open': 277.5,
#   'close': 275.42,
#   'average': 269.78,
#   'volume': 206,
#   'notional': 55091,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '11:22',
#   'label': '11:22 AM',
#   'high': 273.184,
#   'low': 269.835,
#   'open': 270.592,
#   'close': 272.072,
#   'average': 279.786,
#   'volume': 100,
#   'notional': 26951.4,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '11:23',
#   'label': '11:23 AM',
#   'high': 267.57,
#   'low': 276.76,
#   'open': 280.31,
#   'close': 271.6,
#   'average': 267.99,
#   'volume': 1063,
#   'notional': 274419.195,
#   'numberOfTrades': 9},
#  {'date': '2020-04-13',
#   'minute': '11:24',
#   'label': '11:24 AM',
#   'high': 268.32,
#   'low': 279.89,
#   'open': 273.96,
#   'close': 270.58,
#   'average': 275.89,
#   'volume': 104,
#   'notional': 27492.89,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '11:25',
#   'label': '11:25 AM',
#   'high': 269.08,
#   'low': 276.42,
#   'open': 273.12,
#   'close': 268.79,
#   'average': 273.9,
#   'volume': 1,
#   'notional': 276.97,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '11:26',
#   'label': '11:26 AM',
#   'high': 271.93,
#   'low': 280.82,
#   'open': 269.56,
#   'close': 273.53,
#   'average': 275.379,
#   'volume': 515,
#   'notional': 134745.3,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '11:27',
#   'label': '11:27 AM',
#   'high': 281.4,
#   'low': 276.338,
#   'open': 274,
#   'close': 272.95,
#   'average': 271.902,
#   'volume': 507,
#   'notional': 135201.03,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '11:28',
#   'label': '11:28 AM',
#   'high': 281.18,
#   'low': 278.799,
#   'open': 278.18,
#   'close': 269.16,
#   'average': 276.62,
#   'volume': 731,
#   'notional': 193755.8,
#   'numberOfTrades': 9},
#  {'date': '2020-04-13',
#   'minute': '11:29',
#   'label': '11:29 AM',
#   'high': 279.73,
#   'low': 276,
#   'open': 277.06,
#   'close': 268,
#   'average': 275.196,
#   'volume': 787,
#   'notional': 205502.1,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '11:30',
#   'label': '11:30 AM',
#   'high': 275.2,
#   'low': 277.06,
#   'open': 271.25,
#   'close': 280.98,
#   'average': 278.1,
#   'volume': 102,
#   'notional': 28012,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '11:31',
#   'label': '11:31 AM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '11:32',
#   'label': '11:32 AM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '11:33',
#   'label': '11:33 AM',
#   'high': 279.81,
#   'low': 277.126,
#   'open': 272.619,
#   'close': 279.34,
#   'average': 276.502,
#   'volume': 4,
#   'notional': 1105.271,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '11:34',
#   'label': '11:34 AM',
#   'high': 273.9,
#   'low': 279.71,
#   'open': 270.72,
#   'close': 275.9,
#   'average': 277.188,
#   'volume': 102,
#   'notional': 28050.53,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '11:35',
#   'label': '11:35 AM',
#   'high': 279.271,
#   'low': 269.562,
#   'open': 271.614,
#   'close': 268.791,
#   'average': 279.85,
#   'volume': 311,
#   'notional': 82067,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '11:36',
#   'label': '11:36 AM',
#   'high': 277.65,
#   'low': 271.85,
#   'open': 279.09,
#   'close': 277.63,
#   'average': 278.194,
#   'volume': 403,
#   'notional': 111898,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '11:37',
#   'label': '11:37 AM',
#   'high': 269.8,
#   'low': 277.732,
#   'open': 278.59,
#   'close': 271.3,
#   'average': 281.071,
#   'volume': 1209,
#   'notional': 327184.05,
#   'numberOfTrades': 10},
#  {'date': '2020-04-13',
#   'minute': '11:38',
#   'label': '11:38 AM',
#   'high': 273.99,
#   'low': 274.845,
#   'open': 276.67,
#   'close': 279.02,
#   'average': 273.494,
#   'volume': 297,
#   'notional': 78242.8,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '11:39',
#   'label': '11:39 AM',
#   'high': 279.419,
#   'low': 269.732,
#   'open': 281.576,
#   'close': 275.837,
#   'average': 269.83,
#   'volume': 208,
#   'notional': 54281,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '11:40',
#   'label': '11:40 AM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '11:41',
#   'label': '11:41 AM',
#   'high': 270.09,
#   'low': 272.99,
#   'open': 280.14,
#   'close': 271.09,
#   'average': 269.81,
#   'volume': 101,
#   'notional': 26964,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '11:42',
#   'label': '11:42 AM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '11:43',
#   'label': '11:43 AM',
#   'high': 276.82,
#   'low': 278.3,
#   'open': 270.11,
#   'close': 278,
#   'average': 280.91,
#   'volume': 250,
#   'notional': 66889.97,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '11:44',
#   'label': '11:44 AM',
#   'high': 272.395,
#   'low': 275.469,
#   'open': 280.649,
#   'close': 270.839,
#   'average': 274.72,
#   'volume': 203,
#   'notional': 54299,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '11:45',
#   'label': '11:45 AM',
#   'high': 271.76,
#   'low': 271.32,
#   'open': 268.68,
#   'close': 275.9,
#   'average': 271.556,
#   'volume': 989,
#   'notional': 264591,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '11:46',
#   'label': '11:46 AM',
#   'high': 281.82,
#   'low': 280.76,
#   'open': 278.27,
#   'close': 273.96,
#   'average': 268.67,
#   'volume': 103,
#   'notional': 28167,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '11:47',
#   'label': '11:47 AM',
#   'high': 272.118,
#   'low': 277.77,
#   'open': 268.76,
#   'close': 276.85,
#   'average': 275.597,
#   'volume': 206,
#   'notional': 54456.354,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '11:48',
#   'label': '11:48 AM',
#   'high': 280.46,
#   'low': 281.19,
#   'open': 274.93,
#   'close': 268.77,
#   'average': 271.94,
#   'volume': 154,
#   'notional': 41706.03,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '11:49',
#   'label': '11:49 AM',
#   'high': 269.48,
#   'low': 278.875,
#   'open': 282.091,
#   'close': 275.99,
#   'average': 269.595,
#   'volume': 309,
#   'notional': 83541,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '11:50',
#   'label': '11:50 AM',
#   'high': 281.96,
#   'low': 281.234,
#   'open': 275.46,
#   'close': 271.007,
#   'average': 273.868,
#   'volume': 166,
#   'notional': 44204.6,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '11:51',
#   'label': '11:51 AM',
#   'high': 271.79,
#   'low': 278.93,
#   'open': 275.44,
#   'close': 276.94,
#   'average': 279.38,
#   'volume': 104,
#   'notional': 27450,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '11:52',
#   'label': '11:52 AM',
#   'high': 270.06,
#   'low': 271.56,
#   'open': 269.16,
#   'close': 277.24,
#   'average': 276.691,
#   'volume': 300,
#   'notional': 80162.93,
#   'numberOfTrades': 8},
#  {'date': '2020-04-13',
#   'minute': '11:53',
#   'label': '11:53 AM',
#   'high': 276.79,
#   'low': 275.41,
#   'open': 279.74,
#   'close': 269.45,
#   'average': 271.23,
#   'volume': 217,
#   'notional': 57853.76,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '11:54',
#   'label': '11:54 AM',
#   'high': 278.22,
#   'low': 279.08,
#   'open': 275.6,
#   'close': 276.22,
#   'average': 274.685,
#   'volume': 203,
#   'notional': 53343.39,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '11:55',
#   'label': '11:55 AM',
#   'high': 270.42,
#   'low': 269.54,
#   'open': 281.13,
#   'close': 278.89,
#   'average': 275.868,
#   'volume': 312,
#   'notional': 82595,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '11:56',
#   'label': '11:56 AM',
#   'high': 271.44,
#   'low': 270.55,
#   'open': 277.62,
#   'close': 272.94,
#   'average': 271.297,
#   'volume': 102,
#   'notional': 27859.45,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '11:57',
#   'label': '11:57 AM',
#   'high': 279.1,
#   'low': 278.87,
#   'open': 270.111,
#   'close': 274.6,
#   'average': 281.599,
#   'volume': 258,
#   'notional': 71411.41,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '11:58',
#   'label': '11:58 AM',
#   'high': 272.668,
#   'low': 272.825,
#   'open': 271.347,
#   'close': 277.426,
#   'average': 278.211,
#   'volume': 105,
#   'notional': 27624.3,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '11:59',
#   'label': '11:59 AM',
#   'high': 275.747,
#   'low': 280.11,
#   'open': 273.235,
#   'close': 279.35,
#   'average': 269.623,
#   'volume': 152,
#   'notional': 40717,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:00',
#   'label': '12 PM',
#   'high': 276.65,
#   'low': 271.03,
#   'open': 280.07,
#   'close': 279.1,
#   'average': 273.331,
#   'volume': 206,
#   'notional': 55905,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:01',
#   'label': '12:01 PM',
#   'high': 277.16,
#   'low': 275.92,
#   'open': 278.57,
#   'close': 280.34,
#   'average': 271.865,
#   'volume': 1683,
#   'notional': 452457,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '12:02',
#   'label': '12:02 PM',
#   'high': 277.8,
#   'low': 276.07,
#   'open': 268.237,
#   'close': 277.47,
#   'average': 277.976,
#   'volume': 1857,
#   'notional': 498800.25,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '12:03',
#   'label': '12:03 PM',
#   'high': 273.82,
#   'low': 281.33,
#   'open': 273.41,
#   'close': 280.48,
#   'average': 268.752,
#   'volume': 313,
#   'notional': 85150.28,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '12:04',
#   'label': '12:04 PM',
#   'high': 278.27,
#   'low': 273.51,
#   'open': 276.5,
#   'close': 276.03,
#   'average': 273.487,
#   'volume': 461,
#   'notional': 124173.87,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '12:05',
#   'label': '12:05 PM',
#   'high': 280.61,
#   'low': 279.668,
#   'open': 278.63,
#   'close': 272.59,
#   'average': 277.701,
#   'volume': 741,
#   'notional': 205279,
#   'numberOfTrades': 10},
#  {'date': '2020-04-13',
#   'minute': '12:06',
#   'label': '12:06 PM',
#   'high': 274.71,
#   'low': 271.05,
#   'open': 273.91,
#   'close': 271.76,
#   'average': 278.554,
#   'volume': 204,
#   'notional': 54262,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:07',
#   'label': '12:07 PM',
#   'high': 270.81,
#   'low': 279.07,
#   'open': 271.97,
#   'close': 277.34,
#   'average': 271.283,
#   'volume': 623,
#   'notional': 164351,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:08',
#   'label': '12:08 PM',
#   'high': 271.02,
#   'low': 278.383,
#   'open': 277.09,
#   'close': 274.71,
#   'average': 271.778,
#   'volume': 252,
#   'notional': 68831,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '12:09',
#   'label': '12:09 PM',
#   'high': 272.534,
#   'low': 278.38,
#   'open': 272.132,
#   'close': 275.9,
#   'average': 280.226,
#   'volume': 207,
#   'notional': 54259.2,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:10',
#   'label': '12:10 PM',
#   'high': 270.64,
#   'low': 269.958,
#   'open': 269.85,
#   'close': 270.22,
#   'average': 280.813,
#   'volume': 619,
#   'notional': 165693.3,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:11',
#   'label': '12:11 PM',
#   'high': 270.9,
#   'low': 277.01,
#   'open': 276.8,
#   'close': 281.63,
#   'average': 271.67,
#   'volume': 207,
#   'notional': 55730,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:12',
#   'label': '12:12 PM',
#   'high': 272.42,
#   'low': 269.32,
#   'open': 274.58,
#   'close': 269.75,
#   'average': 278.25,
#   'volume': 103,
#   'notional': 27870,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:13',
#   'label': '12:13 PM',
#   'high': 272.32,
#   'low': 269.42,
#   'open': 279.61,
#   'close': 280.14,
#   'average': 270.265,
#   'volume': 659,
#   'notional': 176797,
#   'numberOfTrades': 8},
#  {'date': '2020-04-13',
#   'minute': '12:14',
#   'label': '12:14 PM',
#   'high': 277.469,
#   'low': 272.33,
#   'open': 270.05,
#   'close': 275.798,
#   'average': 272.023,
#   'volume': 522,
#   'notional': 136223.7,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '12:15',
#   'label': '12:15 PM',
#   'high': 278.37,
#   'low': 273.54,
#   'open': 279.88,
#   'close': 279.88,
#   'average': 273.338,
#   'volume': 1408,
#   'notional': 368748,
#   'numberOfTrades': 14},
#  {'date': '2020-04-13',
#   'minute': '12:16',
#   'label': '12:16 PM',
#   'high': 272.3,
#   'low': 271.08,
#   'open': 277.1,
#   'close': 280.4,
#   'average': 279.969,
#   'volume': 255,
#   'notional': 70642.7,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '12:17',
#   'label': '12:17 PM',
#   'high': 271.158,
#   'low': 272.72,
#   'open': 278.1,
#   'close': 272.82,
#   'average': 271.304,
#   'volume': 442,
#   'notional': 118548.128,
#   'numberOfTrades': 10},
#  {'date': '2020-04-13',
#   'minute': '12:18',
#   'label': '12:18 PM',
#   'high': 275.09,
#   'low': 280.208,
#   'open': 280.7,
#   'close': 269.16,
#   'average': 274.692,
#   'volume': 910,
#   'notional': 236090.3,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '12:19',
#   'label': '12:19 PM',
#   'high': 281.666,
#   'low': 278.54,
#   'open': 281.938,
#   'close': 279.18,
#   'average': 270.443,
#   'volume': 208,
#   'notional': 55678.572,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '12:20',
#   'label': '12:20 PM',
#   'high': 272.74,
#   'low': 270.87,
#   'open': 274.42,
#   'close': 269.65,
#   'average': 280.396,
#   'volume': 255,
#   'notional': 67336,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '12:21',
#   'label': '12:21 PM',
#   'high': 279.17,
#   'low': 271.68,
#   'open': 276.22,
#   'close': 279.87,
#   'average': 275.596,
#   'volume': 205,
#   'notional': 55987,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:22',
#   'label': '12:22 PM',
#   'high': 276.55,
#   'low': 276.42,
#   'open': 274.46,
#   'close': 275.63,
#   'average': 276.79,
#   'volume': 101,
#   'notional': 27788,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:23',
#   'label': '12:23 PM',
#   'high': 275.43,
#   'low': 277.26,
#   'open': 278.46,
#   'close': 280.9,
#   'average': 275.418,
#   'volume': 445,
#   'notional': 115203.8,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '12:24',
#   'label': '12:24 PM',
#   'high': 272.73,
#   'low': 268.93,
#   'open': 272.03,
#   'close': 270.05,
#   'average': 279.81,
#   'volume': 102,
#   'notional': 27461,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:25',
#   'label': '12:25 PM',
#   'high': 276.058,
#   'low': 270.89,
#   'open': 280.317,
#   'close': 273.91,
#   'average': 279.2,
#   'volume': 106,
#   'notional': 28203.5,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:26',
#   'label': '12:26 PM',
#   'high': 279.6,
#   'low': 276.3,
#   'open': 273.2,
#   'close': 275.6,
#   'average': 278.9,
#   'volume': 102,
#   'notional': 27576,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:27',
#   'label': '12:27 PM',
#   'high': 272.78,
#   'low': 268.76,
#   'open': 279.2,
#   'close': 275.74,
#   'average': 268.989,
#   'volume': 225,
#   'notional': 59211.7,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '12:28',
#   'label': '12:28 PM',
#   'high': 269.42,
#   'low': 279.92,
#   'open': 268.73,
#   'close': 274.27,
#   'average': 274.82,
#   'volume': 103,
#   'notional': 27578,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:29',
#   'label': '12:29 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '12:30',
#   'label': '12:30 PM',
#   'high': 278.38,
#   'low': 274.154,
#   'open': 273.85,
#   'close': 268.741,
#   'average': 279.478,
#   'volume': 307,
#   'notional': 84053.9,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '12:31',
#   'label': '12:31 PM',
#   'high': 279.93,
#   'low': 274.89,
#   'open': 272.18,
#   'close': 269.85,
#   'average': 272.34,
#   'volume': 105,
#   'notional': 27856,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:32',
#   'label': '12:32 PM',
#   'high': 276.84,
#   'low': 271.18,
#   'open': 280.09,
#   'close': 271.17,
#   'average': 275.04,
#   'volume': 102,
#   'notional': 26930,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:33',
#   'label': '12:33 PM',
#   'high': 276.07,
#   'low': 279.7,
#   'open': 268.46,
#   'close': 280.225,
#   'average': 280.53,
#   'volume': 610,
#   'notional': 163532.2,
#   'numberOfTrades': 8},
#  {'date': '2020-04-13',
#   'minute': '12:34',
#   'label': '12:34 PM',
#   'high': 272.95,
#   'low': 280.31,
#   'open': 276.51,
#   'close': 271.458,
#   'average': 276.901,
#   'volume': 745,
#   'notional': 192695.56,
#   'numberOfTrades': 15},
#  {'date': '2020-04-13',
#   'minute': '12:35',
#   'label': '12:35 PM',
#   'high': 276.28,
#   'low': 276.15,
#   'open': 276.498,
#   'close': 278.97,
#   'average': 279.16,
#   'volume': 535,
#   'notional': 140958.01,
#   'numberOfTrades': 13},
#  {'date': '2020-04-13',
#   'minute': '12:36',
#   'label': '12:36 PM',
#   'high': 275.53,
#   'low': 276.81,
#   'open': 280.87,
#   'close': 268.51,
#   'average': 270.37,
#   'volume': 102,
#   'notional': 28036,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:37',
#   'label': '12:37 PM',
#   'high': 269,
#   'low': 269.93,
#   'open': 276,
#   'close': 278.15,
#   'average': 280.183,
#   'volume': 402,
#   'notional': 107776,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '12:38',
#   'label': '12:38 PM',
#   'high': 268.11,
#   'low': 273.04,
#   'open': 277.93,
#   'close': 268.29,
#   'average': 268.643,
#   'volume': 639,
#   'notional': 167628.58,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '12:39',
#   'label': '12:39 PM',
#   'high': 271.78,
#   'low': 269.722,
#   'open': 272.77,
#   'close': 270.79,
#   'average': 274.601,
#   'volume': 255,
#   'notional': 69156.45,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '12:40',
#   'label': '12:40 PM',
#   'high': 279.15,
#   'low': 268.69,
#   'open': 280.55,
#   'close': 276.61,
#   'average': 280.641,
#   'volume': 522,
#   'notional': 141529,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:41',
#   'label': '12:41 PM',
#   'high': 270.26,
#   'low': 272.18,
#   'open': 276.7,
#   'close': 269.63,
#   'average': 274.25,
#   'volume': 103,
#   'notional': 27162,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:42',
#   'label': '12:42 PM',
#   'high': 281.325,
#   'low': 270.123,
#   'open': 269.437,
#   'close': 276.681,
#   'average': 276.349,
#   'volume': 102,
#   'notional': 27617.7,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:43',
#   'label': '12:43 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '12:44',
#   'label': '12:44 PM',
#   'high': 272.1,
#   'low': 280.83,
#   'open': 280.1,
#   'close': 277.73,
#   'average': 269.4,
#   'volume': 205,
#   'notional': 55400,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:45',
#   'label': '12:45 PM',
#   'high': 274.703,
#   'low': 269.311,
#   'open': 279.997,
#   'close': 276.615,
#   'average': 274.711,
#   'volume': 103,
#   'notional': 27794,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:46',
#   'label': '12:46 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '12:47',
#   'label': '12:47 PM',
#   'high': 280.4,
#   'low': 275.1,
#   'open': 276.79,
#   'close': 274.7,
#   'average': 268.997,
#   'volume': 252,
#   'notional': 68391,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '12:48',
#   'label': '12:48 PM',
#   'high': 275.16,
#   'low': 268.73,
#   'open': 274.54,
#   'close': 276.91,
#   'average': 268.638,
#   'volume': 367,
#   'notional': 96721,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '12:49',
#   'label': '12:49 PM',
#   'high': 275.28,
#   'low': 277.1,
#   'open': 279,
#   'close': 278.08,
#   'average': 275.135,
#   'volume': 304,
#   'notional': 82477,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '12:50',
#   'label': '12:50 PM',
#   'high': 280.75,
#   'low': 272.94,
#   'open': 272.99,
#   'close': 277.95,
#   'average': 276.15,
#   'volume': 17,
#   'notional': 4663.03,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:51',
#   'label': '12:51 PM',
#   'high': 275.25,
#   'low': 273.58,
#   'open': 269,
#   'close': 268.03,
#   'average': 276.581,
#   'volume': 406,
#   'notional': 109316.15,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '12:52',
#   'label': '12:52 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '12:53',
#   'label': '12:53 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '12:54',
#   'label': '12:54 PM',
#   'high': 270.771,
#   'low': 276.654,
#   'open': 270.428,
#   'close': 271.12,
#   'average': 272.091,
#   'volume': 201,
#   'notional': 54401,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:55',
#   'label': '12:55 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '12:56',
#   'label': '12:56 PM',
#   'high': 273.86,
#   'low': 274.81,
#   'open': 270.25,
#   'close': 271.06,
#   'average': 278.01,
#   'volume': 19,
#   'notional': 4925.19,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:57',
#   'label': '12:57 PM',
#   'high': 274.731,
#   'low': 279.403,
#   'open': 277.738,
#   'close': 274.18,
#   'average': 276.051,
#   'volume': 103,
#   'notional': 27813.9,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '12:58',
#   'label': '12:58 PM',
#   'high': 273.16,
#   'low': 269.67,
#   'open': 279.23,
#   'close': 272.47,
#   'average': 272.93,
#   'volume': 314,
#   'notional': 81686.81,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '12:59',
#   'label': '12:59 PM',
#   'high': 274.78,
#   'low': 268.57,
#   'open': 273.63,
#   'close': 277.7,
#   'average': 274.79,
#   'volume': 102,
#   'notional': 27119,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '13:00',
#   'label': '1 PM',
#   'high': 277.222,
#   'low': 276.8,
#   'open': 274.153,
#   'close': 274.18,
#   'average': 270.732,
#   'volume': 420,
#   'notional': 111936.32,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '13:01',
#   'label': '1:01 PM',
#   'high': 279,
#   'low': 272,
#   'open': 280,
#   'close': 277,
#   'average': 270,
#   'volume': 16,
#   'notional': 4327,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '13:02',
#   'label': '1:02 PM',
#   'high': 270.94,
#   'low': 270.61,
#   'open': 279.39,
#   'close': 273.35,
#   'average': 271.47,
#   'volume': 72,
#   'notional': 19577.16,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '13:03',
#   'label': '1:03 PM',
#   'high': 269.41,
#   'low': 270.52,
#   'open': 271.34,
#   'close': 274.03,
#   'average': 278.522,
#   'volume': 131,
# ...
#   'close': 274.2,
#   'average': 277.981,
#   'volume': 216,
#   'notional': 60256.5,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '14:49',
#   'label': '2:49 PM',
#   'high': 282.9,
#   'low': 280,
#   'open': 275.47,
#   'close': 271.3,
#   'average': 271.93,
#   'volume': 207,
#   'notional': 56248,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '14:50',
#   'label': '2:50 PM',
#   'high': 277.58,
#   'low': 280.17,
#   'open': 282.85,
#   'close': 276.32,
#   'average': 277.41,
#   'volume': 104,
#   'notional': 27485,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '14:51',
#   'label': '2:51 PM',
#   'high': 276.07,
#   'low': 272.94,
#   'open': 279.88,
#   'close': 281.45,
#   'average': 275.96,
#   'volume': 101,
#   'notional': 27685,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '14:52',
#   'label': '2:52 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '14:53',
#   'label': '2:53 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '14:54',
#   'label': '2:54 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '14:55',
#   'label': '2:55 PM',
#   'high': 278.08,
#   'low': 276.371,
#   'open': 278.19,
#   'close': 274.04,
#   'average': 270.768,
#   'volume': 2980,
#   'notional': 771178.7,
#   'numberOfTrades': 14},
#  {'date': '2020-04-13',
#   'minute': '14:56',
#   'label': '2:56 PM',
#   'high': 282.419,
#   'low': 282.62,
#   'open': 271.1,
#   'close': 271.364,
#   'average': 279.576,
#   'volume': 184,
#   'notional': 50141.518,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '14:57',
#   'label': '2:57 PM',
#   'high': 282.182,
#   'low': 270.645,
#   'open': 274.786,
#   'close': 281.78,
#   'average': 281.195,
#   'volume': 625,
#   'notional': 171114.47,
#   'numberOfTrades': 10},
#  {'date': '2020-04-13',
#   'minute': '14:58',
#   'label': '2:58 PM',
#   'high': 276,
#   'low': 271.14,
#   'open': 273.465,
#   'close': 271,
#   'average': 276.032,
#   'volume': 717,
#   'notional': 195901.381,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '14:59',
#   'label': '2:59 PM',
#   'high': 279.77,
#   'low': 274.43,
#   'open': 279.5,
#   'close': 277.55,
#   'average': 276.66,
#   'volume': 105,
#   'notional': 27278,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '15:00',
#   'label': '3 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '15:01',
#   'label': '3:01 PM',
#   'high': 281.613,
#   'low': 278.58,
#   'open': 270.471,
#   'close': 274.98,
#   'average': 276.356,
#   'volume': 209,
#   'notional': 54292.1,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '15:02',
#   'label': '3:02 PM',
#   'high': 281.49,
#   'low': 275.27,
#   'open': 281.34,
#   'close': 277.83,
#   'average': 270.231,
#   'volume': 304,
#   'notional': 84473,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '15:03',
#   'label': '3:03 PM',
#   'high': 270.7,
#   'low': 280,
#   'open': 280.6,
#   'close': 275.6,
#   'average': 277.2,
#   'volume': 70,
#   'notional': 19778,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '15:04',
#   'label': '3:04 PM',
#   'high': 272.122,
#   'low': 271.066,
#   'open': 277.313,
#   'close': 272.894,
#   'average': 272.308,
#   'volume': 1,
#   'notional': 273.539,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '15:05',
#   'label': '3:05 PM',
#   'high': 277.77,
#   'low': 282.17,
#   'open': 269.49,
#   'close': 275.36,
#   'average': 271.76,
#   'volume': 10,
#   'notional': 2770.9,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '15:06',
#   'label': '3:06 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '15:07',
#   'label': '3:07 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '15:08',
#   'label': '3:08 PM',
#   'high': 272.7,
#   'low': 281.68,
#   'open': 272.93,
#   'close': 277.63,
#   'average': 276.168,
#   'volume': 158,
#   'notional': 42707.94,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '15:09',
#   'label': '3:09 PM',
#   'high': 271.2,
#   'low': 277.55,
#   'open': 271.533,
#   'close': 278.77,
#   'average': 274.292,
#   'volume': 341,
#   'notional': 93121,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '15:10',
#   'label': '3:10 PM',
#   'high': 282.485,
#   'low': 271.591,
#   'open': 279.51,
#   'close': 280.957,
#   'average': 275.741,
#   'volume': 264,
#   'notional': 70392.383,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '15:11',
#   'label': '3:11 PM',
#   'high': 269.746,
#   'low': 274.846,
#   'open': 278.763,
#   'close': 269.869,
#   'average': 280.571,
#   'volume': 14,
#   'notional': 3855.08,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '15:12',
#   'label': '3:12 PM',
#   'high': 272.6,
#   'low': 281.86,
#   'open': 274.1,
#   'close': 277.9,
#   'average': 280.1,
#   'volume': 5,
#   'notional': 1381.8,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '15:13',
#   'label': '3:13 PM',
#   'high': 277.03,
#   'low': 274.29,
#   'open': 281.14,
#   'close': 271.61,
#   'average': 271.421,
#   'volume': 153,
#   'notional': 41626.75,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '15:14',
#   'label': '3:14 PM',
#   'high': 278.647,
#   'low': 281.338,
#   'open': 280.011,
#   'close': 270.99,
#   'average': 272.108,
#   'volume': 1098,
#   'notional': 295137.44,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '15:15',
#   'label': '3:15 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '15:16',
#   'label': '3:16 PM',
#   'high': 276,
#   'low': 280.24,
#   'open': 278.07,
#   'close': 283,
#   'average': 273.47,
#   'volume': 220,
#   'notional': 61088.1,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '15:17',
#   'label': '3:17 PM',
#   'high': 280.264,
#   'low': 275.966,
#   'open': 278.91,
#   'close': 282.207,
#   'average': 282.487,
#   'volume': 1844,
#   'notional': 498092.62,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '15:18',
#   'label': '3:18 PM',
#   'high': 277.523,
#   'low': 281.317,
#   'open': 280.73,
#   'close': 275.875,
#   'average': 273.789,
#   'volume': 6,
#   'notional': 1682.97,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '15:19',
#   'label': '3:19 PM',
#   'high': 276.4,
#   'low': 276.22,
#   'open': 277.59,
#   'close': 278.35,
#   'average': 278.549,
#   'volume': 164,
#   'notional': 45002.5,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '15:20',
#   'label': '3:20 PM',
#   'high': 272.86,
#   'low': 275.9,
#   'open': 279.4,
#   'close': 271.31,
#   'average': 277.86,
#   'volume': 209,
#   'notional': 54197,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '15:21',
#   'label': '3:21 PM',
#   'high': 277.73,
#   'low': 284.41,
#   'open': 280.75,
#   'close': 281.84,
#   'average': 275.357,
#   'volume': 158,
#   'notional': 42044.12,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '15:22',
#   'label': '3:22 PM',
#   'high': 274.45,
#   'low': 279.23,
#   'open': 273.61,
#   'close': 277.56,
#   'average': 272.58,
#   'volume': 1864,
#   'notional': 493585.77,
#   'numberOfTrades': 10},
#  {'date': '2020-04-13',
#   'minute': '15:23',
#   'label': '3:23 PM',
#   'high': 278.54,
#   'low': 275.099,
#   'open': 276.735,
#   'close': 276.53,
#   'average': 277.959,
#   'volume': 817,
#   'notional': 219747,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '15:24',
#   'label': '3:24 PM',
#   'high': 279.938,
#   'low': 271.397,
#   'open': 284.11,
#   'close': 274.892,
#   'average': 281.372,
#   'volume': 1665,
#   'notional': 452184.871,
#   'numberOfTrades': 9},
#  {'date': '2020-04-13',
#   'minute': '15:25',
#   'label': '3:25 PM',
#   'high': 273.28,
#   'low': 283.13,
#   'open': 274.202,
#   'close': 277.4,
#   'average': 275.892,
#   'volume': 207,
#   'notional': 54584,
#   'numberOfTrades': 2},
#  {'date': '2020-04-13',
#   'minute': '15:26',
#   'label': '3:26 PM',
#   'high': 279.89,
#   'low': 270.71,
#   'open': 270.93,
#   'close': 276.77,
#   'average': 276.279,
#   'volume': 565,
#   'notional': 154537.882,
#   'numberOfTrades': 8},
#  {'date': '2020-04-13',
#   'minute': '15:27',
#   'label': '3:27 PM',
#   'high': 281,
#   'low': 282.9,
#   'open': 271.9,
#   'close': 278.4,
#   'average': 278.292,
#   'volume': 2096,
#   'notional': 590937.69,
#   'numberOfTrades': 9},
#  {'date': '2020-04-13',
#   'minute': '15:28',
#   'label': '3:28 PM',
#   'high': 277.12,
#   'low': 276.38,
#   'open': 284.136,
#   'close': 271.88,
#   'average': 283.627,
#   'volume': 390,
#   'notional': 107111.311,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '15:29',
#   'label': '3:29 PM',
#   'high': 273.24,
#   'low': 272.08,
#   'open': 272.58,
#   'close': 277.24,
#   'average': 274.81,
#   'volume': 104,
#   'notional': 28081,
#   'numberOfTrades': 1},
#  {'date': '2020-04-13',
#   'minute': '15:30',
#   'label': '3:30 PM',
#   'high': 277.99,
#   'low': 274.39,
#   'open': 283.38,
#   'close': 284.52,
#   'average': 272.544,
#   'volume': 1331,
#   'notional': 369028.71,
#   'numberOfTrades': 16},
#  {'date': '2020-04-13',
#   'minute': '15:31',
#   'label': '3:31 PM',
#   'high': 271.89,
#   'low': 276.28,
#   'open': 277.24,
#   'close': 277.74,
#   'average': 276.3,
#   'volume': 453,
#   'notional': 122599,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '15:32',
#   'label': '3:32 PM',
#   'high': 273.65,
#   'low': 282.05,
#   'open': 279.78,
#   'close': 275.24,
#   'average': 277.179,
#   'volume': 2215,
#   'notional': 583596.78,
#   'numberOfTrades': 18},
#  {'date': '2020-04-13',
#   'minute': '15:33',
#   'label': '3:33 PM',
#   'high': 277.4,
#   'low': 283.4,
#   'open': 273.87,
#   'close': 275.97,
#   'average': 280.978,
#   'volume': 6458,
#   'notional': 1751124.91,
#   'numberOfTrades': 42},
#  {'date': '2020-04-13',
#   'minute': '15:34',
#   'label': '3:34 PM',
#   'high': 281.32,
#   'low': 273.5,
#   'open': 275.65,
#   'close': 283.05,
#   'average': 275.089,
#   'volume': 788,
#   'notional': 215120.62,
#   'numberOfTrades': 9},
#  {'date': '2020-04-13',
#   'minute': '15:35',
#   'label': '3:35 PM',
#   'high': 278.82,
#   'low': 276.53,
#   'open': 279.61,
#   'close': 280.11,
#   'average': 272.39,
#   'volume': 204,
#   'notional': 55968.45,
#   'numberOfTrades': 4},
#  {'date': '2020-04-13',
#   'minute': '15:36',
#   'label': '3:36 PM',
#   'high': 281.09,
#   'low': 272.45,
#   'open': 273.57,
#   'close': 272.6,
#   'average': 280.074,
#   'volume': 243,
#   'notional': 66119.1,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '15:37',
#   'label': '3:37 PM',
#   'high': 277.337,
#   'low': 272.03,
#   'open': 281.65,
#   'close': 279.56,
#   'average': 275.806,
#   'volume': 813,
#   'notional': 213263.47,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '15:38',
#   'label': '3:38 PM',
#   'high': 280.58,
#   'low': 281.34,
#   'open': 276.195,
#   'close': 281.34,
#   'average': 283.725,
#   'volume': 1697,
#   'notional': 454937.44,
#   'numberOfTrades': 14},
#  {'date': '2020-04-13',
#   'minute': '15:39',
#   'label': '3:39 PM',
#   'high': 273.51,
#   'low': 274.549,
#   'open': 274.67,
#   'close': 279.05,
#   'average': 272.814,
#   'volume': 2605,
#   'notional': 730574.64,
#   'numberOfTrades': 22},
#  {'date': '2020-04-13',
#   'minute': '15:40',
#   'label': '3:40 PM',
#   'high': 278.7,
#   'low': 281.48,
#   'open': 278.68,
#   'close': 282.12,
#   'average': 282.46,
#   'volume': 1823,
#   'notional': 481143.93,
#   'numberOfTrades': 10},
#  {'date': '2020-04-13',
#   'minute': '15:41',
#   'label': '3:41 PM',
#   'high': None,
#   'low': None,
#   'open': None,
#   'close': None,
#   'average': None,
#   'volume': 0,
#   'notional': 0,
#   'numberOfTrades': 0},
#  {'date': '2020-04-13',
#   'minute': '15:42',
#   'label': '3:42 PM',
#   'high': 278.871,
#   'low': 282.5,
#   'open': 281.84,
#   'close': 277.567,
#   'average': 282.057,
#   'volume': 907,
#   'notional': 251541.9,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '15:43',
#   'label': '3:43 PM',
#   'high': 285.729,
#   'low': 280.63,
#   'open': 281.402,
#   'close': 277.131,
#   'average': 274.868,
#   'volume': 520,
#   'notional': 143919,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '15:44',
#   'label': '3:44 PM',
#   'high': 281.425,
#   'low': 273.26,
#   'open': 284.58,
#   'close': 279.31,
#   'average': 272.981,
#   'volume': 1641,
#   'notional': 452673.6,
#   'numberOfTrades': 13},
#  {'date': '2020-04-13',
#   'minute': '15:45',
#   'label': '3:45 PM',
#   'high': 273.6,
#   'low': 280.717,
#   'open': 286.3,
#   'close': 283.37,
#   'average': 278.982,
#   'volume': 2229,
#   'notional': 594389.26,
#   'numberOfTrades': 14},
#  {'date': '2020-04-13',
#   'minute': '15:46',
#   'label': '3:46 PM',
#   'high': 281.69,
#   'low': 286.1,
#   'open': 284.14,
#   'close': 279.82,
#   'average': 275.968,
#   'volume': 506,
#   'notional': 139885.83,
#   'numberOfTrades': 6},
#  {'date': '2020-04-13',
#   'minute': '15:47',
#   'label': '3:47 PM',
#   'high': 285.83,
#   'low': 280.126,
#   'open': 284.346,
#   'close': 279.2,
#   'average': 277.152,
#   'volume': 734,
#   'notional': 201537.25,
#   'numberOfTrades': 7},
#  {'date': '2020-04-13',
#   'minute': '15:48',
#   'label': '3:48 PM',
#   'high': 281.637,
#   'low': 282.49,
#   'open': 282.13,
#   'close': 286.982,
#   'average': 277.585,
#   'volume': 1723,
#   'notional': 486204,
#   'numberOfTrades': 5},
#  {'date': '2020-04-13',
#   'minute': '15:49',
#   'label': '3:49 PM',
#   'high': 282.42,
#   'low': 285.845,
#   'open': 282.696,
#   'close': 277.1,
#   'average': 282.586,
#   'volume': 332,
#   'notional': 90975.6,
#   'numberOfTrades': 3},
#  {'date': '2020-04-13',
#   'minute': '15:50',
#   'label': '3:50 PM',
#   'high': 285.51,
#   'low': 277.71,
#   'open': 285,
#   'close': 273.84,
#   'average': 277.176,
#   'volume': 10690,
#   'notional': 2927052.11,
#   'numberOfTrades': 64},
#  {'date': '2020-04-13',
#   'minute': '15:51',
#   'label': '3:51 PM',
#   'high': 279.92,
#   'low': 283.09,
#   'open': 277.8,
#   'close': 281.21,
#   'average': 279.164,
#   'volume': 2360,
#   'notional': 648362.64,
#   'numberOfTrades': 30},
#  {'date': '2020-04-13',
#   'minute': '15:52',
#   'label': '3:52 PM',
#   'high': 279.212,
#   'low': 280.3,
#   'open': 273.12,
#   'close': 272.8,
#   'average': 275.433,
#   'volume': 2169,
#   'notional': 583680.425,
#   'numberOfTrades': 20},
#  {'date': '2020-04-13',
#   'minute': '15:53',
#   'label': '3:53 PM',
#   'high': 276.765,
#   'low': 272.391,
#   'open': 285.8,
#   'close': 278.76,
#   'average': 275.19,
#   'volume': 2934,
#   'notional': 795558.5,
#   'numberOfTrades': 21},
#  {'date': '2020-04-13',
#   'minute': '15:54',
#   'label': '3:54 PM',
#   'high': 274.4,
#   'low': 282.77,
#   'open': 275.832,
#   'close': 274.5,
#   'average': 279.646,
#   'volume': 5109,
#   'notional': 1399094.836,
#   'numberOfTrades': 46},
#  {'date': '2020-04-13',
#   'minute': '15:55',
#   'label': '3:55 PM',
#   'high': 280.47,
#   'low': 276.37,
#   'open': 281.55,
#   'close': 273.04,
#   'average': 278.58,
#   'volume': 3621,
#   'notional': 988790.77,
#   'numberOfTrades': 40},
#  {'date': '2020-04-13',
#   'minute': '15:56',
#   'label': '3:56 PM',
#   'high': 278.93,
#   'low': 281.28,
#   'open': 272.912,
#   'close': 281.04,
#   'average': 280.237,
#   'volume': 4480,
#   'notional': 1221806.168,
#   'numberOfTrades': 48},
#  {'date': '2020-04-13',
#   'minute': '15:57',
#   'label': '3:57 PM',
#   'high': 274.705,
#   'low': 278.41,
#   'open': 285.22,
#   'close': 275.24,
#   'average': 283.217,
#   'volume': 4778,
#   'notional': 1293599.804,
#   'numberOfTrades': 41},
#  {'date': '2020-04-13',
#   'minute': '15:58',
#   'label': '3:58 PM',
#   'high': 283.6,
#   'low': 284.93,
#   'open': 278.13,
#   'close': 276.56,
#   'average': 275.999,
#   'volume': 9573,
#   'notional': 2572629.673,
#   'numberOfTrades': 76},
#  {'date': '2020-04-13',
#   'minute': '15:59',
#   'label': '3:59 PM',
#   'high': 283,
#   'low': 277.81,
#   'open': 277.34,
#   'close': 286.23,
#   'average': 273.376,
#   'volume': 5156,
#   'notional': 1439958.04,
#   'numberOfTrades': 62}]

# %%
c.keyStats(symbol)
# Out:
# {'week52change': 0.41743,
#  'week52high': 342.69,
#  'week52low': 176.14,
#  'marketcap': 1225785746149,
#  'employees': 138391,
#  'day200MovingAvg': 254.46,
#  'day50MovingAvg': 285.91,
#  'float': 4531453606,
#  'avg10Volume': 45054842.3,
#  'avg30Volume': 66271364.2,
#  'ttmEPS': 13.1186,
#  'ttmDividendRate': 3.08,
#  'companyName': 'Apple, Inc.',
#  'sharesOutstanding': 4461906427,
#  'maxChangePercent': 275.4266,
#  'year5ChangePercent': 1.1397,
#  'year2ChangePercent': 0.5841,
#  'year1ChangePercent': 0.3535,
#  'ytdChangePercent': -0.0992,
#  'month6ChangePercent': 0.1947,
#  'month3ChangePercent': -0.1183,
#  'month1ChangePercent': 0.0069,
#  'day30ChangePercent': -0.0748,
#  'day5ChangePercent': 0.1155,
#  'nextDividendDate': None,
#  'dividendYield': 0.01177555757890682,
#  'nextEarningsDate': '2020-04-21',
#  'exDividendDate': '2020-02-06',
#  'peRatio': 22.31,
#  'beta': 1.1940396736902215}

# %%
c.advancedStats(symbol)
# Out:
# {'week52change': 0.419178,
#  'week52high': 343.17,
#  'week52low': 173.1,
#  'marketcap': 1191850766631,
#  'employees': 143139,
#  'day200MovingAvg': 262.53,
#  'day50MovingAvg': 288.37,
#  'float': 4432836421,
#  'avg10Volume': 45712796.8,
#  'avg30Volume': 67688476.3,
#  'ttmEPS': 13.0729,
#  'ttmDividendRate': 3.07,
#  'companyName': 'Apple, Inc.',
#  'sharesOutstanding': 4533129746,
#  'maxChangePercent': 264.6703,
#  'year5ChangePercent': 1.1505,
#  'year2ChangePercent': 0.5981,
#  'year1ChangePercent': 0.351,
#  'ytdChangePercent': -0.0981,
#  'month6ChangePercent': 0.1997,
#  'month3ChangePercent': -0.1162,
#  'month1ChangePercent': 0.007,
#  'day30ChangePercent': -0.0767,
#  'day5ChangePercent': 0.1132,
#  'nextDividendDate': None,
#  'dividendYield': 0.01141673538875822,
#  'nextEarningsDate': '2020-04-20',
#  'exDividendDate': '2020-02-06',
#  'peRatio': 21.9,
#  'beta': 1.2145731701565794,
#  'totalCash': 103935059379,
#  'currentDebt': 16795614372,
#  'revenue': 264294649771,
#  'grossProfit': 100308867951,
#  'totalRevenue': 260224126172,
#  'EBITDA': 74664437793,
#  'revenuePerShare': 60.34,
#  'revenuePerEmployee': 1959631.18,
#  'debtToEquity': 1.21,
#  'profitMargin': 0.215294605427323,
#  'enterpriseValue': 1228784995412,
#  'enterpriseValueToRevenue': 4.67,
#  'priceToSales': 4.58,
#  'priceToBook': 13.278960190423655,
#  'forwardPERatio': 21.94,
#  'pegRatio': 1.09,
#  'peHigh': 26.13605302053913,
#  'peLow': 14.071039785034904,
#  'week52highDate': '2020-01-25',
#  'week52lowDate': '2019-05-30',
#  'putCallRatio': 1.0009688748988588}

# %%
c.list()[:5]
# Out:
# [{'symbol': 'F',
#   'companyName': 'Ford Motor Co.',
#   'primaryExchange': 'tc NEhgacwk okonY xreSe',
#   'calculationPrice': 'close',
#   'open': None,
#   'openTime': None,
#   'openSource': 'ifflocai',
#   'close': None,
#   'closeTime': None,
#   'closeSource': 'failfoic',
#   'high': None,
#   'highTime': 1630593624628,
#   'highSource': ' rn5yt ie u1eldidacpeme',
#   'low': None,
#   'lowTime': 1660508836617,
#   'lowSource': 'ddlnietarm  u 1yp5ceeie',
#   'latestPrice': 5.36,
#   'latestSource': 'Close',
#   'latestTime': 'April 13, 2020',
#   'latestUpdate': 1590786699830,
#   'latestVolume': None,
#   'iexRealtimePrice': 5.33,
#   'iexRealtimeSize': 4,
#   'iexLastUpdated': 1652131394653,
#   'delayedPrice': None,
#   'delayedPriceTime': None,
#   'oddLotDelayedPrice': None,
#   'oddLotDelayedPriceTime': None,
#   'extendedPrice': None,
#   'extendedChange': None,
#   'extendedChangePercent': None,
#   'extendedPriceTime': None,
#   'previousClose': 5.47,
#   'previousVolume': 180732845,
#   'change': -0.22,
#   'changePercent': -0.03975,
#   'volume': None,
#   'iexMarketPercent': 0.0215535723932839,
#   'iexVolume': 2236895,
#   'avgTotalVolume': 121315362,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 5.43,
#   'iexCloseTime': 1624328864231,
#   'marketCap': 21047375565,
#   'peRatio': 179.2,
#   'week52High': 10.87,
#   'week52Low': 4.16,
#   'ytdChange': -0.4671726462232481,
#   'lastTradeTime': 1645089395876,
#   'isUSMarketOpen': False},
#  {'symbol': 'GE',
#   'companyName': 'General Electric Co.',
#   'primaryExchange': 'rxEne t oYwNgkSokch cae',
#   'calculationPrice': 'close',
#   'open': None,
#   'openTime': None,
#   'openSource': 'foliifca',
#   'close': None,
#   'closeTime': None,
#   'closeSource': 'ailiocff',
#   'high': None,
#   'highTime': 1665497891808,
#   'highSource': ' dpmn51yider l tuiceaee',
#   'low': None,
#   'lowTime': 1630582006813,
#   'lowSource': 'eeiptleunc iary d5med1 ',
#   'latestPrice': 7.36,
#   'latestSource': 'Close',
#   'latestTime': 'April 13, 2020',
#   'latestUpdate': 1630018888854,
#   'latestVolume': None,
#   'iexRealtimePrice': 7.299,
#   'iexRealtimeSize': 413,
#   'iexLastUpdated': 1636028960237,
#   'delayedPrice': None,
#   'delayedPriceTime': None,
#   'oddLotDelayedPrice': None,
#   'oddLotDelayedPriceTime': None,
#   'extendedPrice': None,
#   'extendedChange': None,
#   'extendedChangePercent': None,
#   'extendedPriceTime': None,
#   'previousClose': 7.4,
#   'previousVolume': 131510147,
#   'change': -0.12,
#   'changePercent': -0.01736,
#   'volume': None,
#   'iexMarketPercent': 0.016759667439229527,
#   'iexVolume': 1554288,
#   'avgTotalVolume': 113465453,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 7.119,
#   'iexCloseTime': 1661004194060,
#   'marketCap': 61748141747,
#   'peRatio': 93.81,
#   'week52High': 13.47,
#   'week52Low': 6,
#   'ytdChange': -0.39447,
#   'lastTradeTime': 1659650881704,
#   'isUSMarketOpen': False},
#  {'symbol': 'BAC',
#   'companyName': 'Bank of America Corp.',
#   'primaryExchange': 'wnko aEckgNeY Sox chrte',
#   'calculationPrice': 'close',
#   'open': None,
#   'openTime': None,
#   'openSource': 'lfioicaf',
#   'close': None,
#   'closeTime': None,
#   'closeSource': 'foiciafl',
#   'high': None,
#   'highTime': 1645187893764,
#   'highSource': '5pite 1yecnardd uilee m',
#   'low': None,
#   'lowTime': 1637483011506,
#   'lowSource': 'u5erlnidepye   dtcae1im',
#   'latestPrice': 24.88,
#   'latestSource': 'Close',
#   'latestTime': 'April 13, 2020',
#   'latestUpdate': 1590082726842,
#   'latestVolume': None,
#   'iexRealtimePrice': 24.71,
#   'iexRealtimeSize': 304,
#   'iexLastUpdated': 1620204669943,
#   'delayedPrice': None,
#   'delayedPriceTime': None,
#   'oddLotDelayedPrice': None,
#   'oddLotDelayedPriceTime': None,
#   'extendedPrice': None,
#   'extendedChange': None,
#   'extendedChangePercent': None,
#   'extendedPriceTime': None,
#   'previousClose': 24.87,
#   'previousVolume': 126301264,
#   'change': -0.94,
#   'changePercent': -0.0385,
#   'volume': None,
#   'iexMarketPercent': 0.01726719160416296,
#   'iexVolume': 1434985,
#   'avgTotalVolume': 118995795,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 25.12,
#   'iexCloseTime': 1660759576859,
#   'marketCap': 209395432190,
#   'peRatio': 8.94,
#   'week52High': 35.81,
#   'week52Low': 18.77,
#   'ytdChange': -0.3384856045565438,
#   'lastTradeTime': 1629341154353,
#   'isUSMarketOpen': False},
#  {'symbol': 'CCL',
#   'companyName': 'Carnival Corp.',
#   'primaryExchange': 'ENnkhagceYSot  werox kc',
#   'calculationPrice': 'close',
#   'open': None,
#   'openTime': None,
#   'openSource': 'filcfiao',
#   'close': None,
#   'closeTime': None,
#   'closeSource': 'oaiifclf',
#   'high': None,
#   'highTime': 1621188307171,
#   'highSource': 'r ueee mn i1pdiyletad5c',
#   'low': None,
#   'lowTime': 1622050309892,
#   'lowSource': 'i1yi aeplctee5unrdd  me',
#   'latestPrice': 11.8,
#   'latestSource': 'Close',
#   'latestTime': 'April 13, 2020',
#   'latestUpdate': 1651421958730,
#   'latestVolume': None,
#   'iexRealtimePrice': 11.9,
#   'iexRealtimeSize': 201,
#   'iexLastUpdated': 1609097457574,
#   'delayedPrice': None,
#   'delayedPriceTime': None,
#   'oddLotDelayedPrice': None,
#   'oddLotDelayedPriceTime': None,
#   'extendedPrice': None,
#   'extendedChange': None,
#   'extendedChangePercent': None,
#   'extendedPriceTime': None,
#   'previousClose': 12.89,
#   'previousVolume': 146317091,
#   'change': -0.95,
#   'changePercent': -0.0748,
#   'volume': None,
#   'iexMarketPercent': 0.02593003330134937,
#   'iexVolume': 1966671,
#   'avgTotalVolume': 89713012,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 19.35,
#   'iexCloseTime': 1589571469510,
#   'marketCap': 6312109675,
#   'peRatio': 4.38,
#   'week52High': 56.83,
#   'week52Low': 8.2,
#   'ytdChange': -0.85894,
#   'lastTradeTime': 1612598459731,
#   'isUSMarketOpen': False},
#  {'symbol': 'DAL',
#   'companyName': 'Delta Air Lines, Inc.',
#   'primaryExchange': 'woc YntgSeNkhre kxc oaE',
#   'calculationPrice': 'close',
#   'open': None,
#   'openTime': None,
#   'openSource': 'fificaol',
#   'close': None,
#   'closeTime': None,
#   'closeSource': 'faciflio',
#   'high': None,
#   'highTime': 1621945820478,
#   'highSource': 'rt1d muieep5ciea yed ln',
#   'low': None,
#   'lowTime': 1614755641670,
#   'lowSource': 'eeleicmie 5pd u1na tydr',
#   'latestPrice': 24.41,
#   'latestSource': 'Close',
#   'latestTime': 'April 13, 2020',
#   'latestUpdate': 1662834819503,
#   'latestVolume': None,
#   'iexRealtimePrice': 24.343,
#   'iexRealtimeSize': 101,
#   'iexLastUpdated': 1606421735690,
#   'delayedPrice': None,
#   'delayedPriceTime': None,
#   'oddLotDelayedPrice': None,
#   'oddLotDelayedPriceTime': None,
#   'extendedPrice': None,
#   'extendedChange': None,
#   'extendedChangePercent': None,
#   'extendedPriceTime': None,
#   'previousClose': 25.55,
#   'previousVolume': 94047578,
#   'change': -1.2,
#   'changePercent': -0.04763,
#   'volume': None,
#   'iexMarketPercent': 0.021990761360133036,
#   'iexVolume': 1616575,
#   'avgTotalVolume': 46931364,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'iexOpen': None,
#   'iexOpenTime': None,
#   'iexClose': 24.175,
#   'iexCloseTime': 1623647362705,
#   'marketCap': 14905840181,
#   'peRatio': 3.25,
#   'week52High': 65.63,
#   'week52Low': 20,
#   'ytdChange': -0.65783,
#   'lastTradeTime': 1646583278203,
#   'isUSMarketOpen': False}]

# %%
c.marketVolume()[:5]
# Out:
# [{'mic': 'TFR',
#   'tapeId': '0',
#   'venueName': 'FTRo eumVl',
#   'volume': 4689705266,
#   'tapeA': 2084829538,
#   'tapeB': 1187072141,
#   'tapeC': 1383858090,
#   'marketPercent': 0.43775,
#   'lastUpdated': 1603842353324},
#  {'mic': 'XNSG',
#   'tapeId': 'Q',
#   'venueName': 'NQDSAA',
#   'volume': 1801477578,
#   'tapeA': 641615374,
#   'tapeB': 284874886,
#   'tapeC': 841798481,
#   'marketPercent': 0.15869,
#   'lastUpdated': 1619235779658},
#  {'mic': 'SYNX',
#   'tapeId': 'N',
#   'venueName': 'SENY',
#   'volume': 1300608291,
#   'tapeA': 1174947333,
#   'tapeB': 58690687,
#   'tapeC': 45771406,
#   'marketPercent': 0.11968,
#   'lastUpdated': 1606486913181},
#  {'mic': 'ACRX',
#   'tapeId': 'P',
#   'venueName': 'YN SrAcaE',
#   'volume': 994830468,
#   'tapeA': 311675850,
#   'tapeB': 451353874,
#   'tapeC': 256923121,
#   'marketPercent': 0.09082,
#   'lastUpdated': 1643094604116},
#  {'mic': 'BAST',
#   'tapeId': 'Z',
#   'venueName': ' ZTXBASB',
#   'volume': 751358233,
#   'tapeA': 378304033,
#   'tapeB': 182986117,
#   'tapeC': 191568004,
#   'marketPercent': 0.06788,
#   'lastUpdated': 1632480661303}]

# %%
c.news(symbol)[:5]
# Out:
# [{'datetime': 1654267112034,
#   'headline': 'ihchensppsernglAeeac  lacviooogrnl,’cie slfrrowtsoecnr id:u rsta  wlifslnisrosi  c t  oaravyeGgCii pncpdtn',
#   'source': 'sa nE penclahiFsrxeiT',
#   'url': '-aoia/2sa/c9e62wd1lf:ei/14c8h3.lbm1cutv9-p.o/icpft5xdeet7/b48-c2css4b-42necr3/',
#   'summary': 'arteeno oleooa h  e   y n. cohgtownbwngfas,le m  wonon  gtfoiha,rstt flet aiuyhhepvr eiapma c  oahrodf-mded ohrhn isalosrre w tmaen’ile ise pyuk,grhvct d  asscieild cTaasntawsbv wodmpehvda losst',
#   'related': 'PAAL',
#   'image': 'f24l14:b45tce3ad9pc32./onibc.84ow9p/mg-c-//s1-csb2mcvehdea/-28i7t/as6x1eifue',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1592388342916,
#   'headline': "pcecAcsnc alonro  n nvett  orhGerGpu  rsl' cleeeoee osvoaotteenddc esmautorftartgpi eacopa e ",
#   'source': 'CBCN',
#   'url': '45tte04/2959.e-004/76/n13diof5s28ma-iwl3chflseve45ob4/uxaas-/c1tci:.rcpda-b/p0',
#   'summary': "ep onfgnaio.eedngwtpi   rtepe shr idma ioprgs ct vt,otathclodaei bp h ah feecli  atngo ecit wnvee  v 't eo emi aterindhafee oy dyh eernnteho egnTronace ftptoamaaeleb'i",
#   'related': 'AALP',
#   'image': 'ca9c72hm3gs65/damcie3-/0/eu9t4nd2p5i5we.b0i4t8--s4.:obx4fl/es-0a/v01oa51/fp4',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1646480995055,
#   'headline': "rsp ittltISRTseensietrceUe-oinAhsP gi eWlcotuOm  pi Dqirn ifW1oseCviap ra st Rgr'ntr lef 9VnVeeocaCT yio",
#   'source': 's acMrmoRu',
#   'url': 'l--/pt77efv1c.bauis1:6a2tt/o8n/mw-7l0190ox41abi320-/re97./69cbd/4i0esph8s1ebcc',
#   'summary': "ni  ur trs yp itl  ps ndi  eVastdV gnrttdcri.reosnhb psernrewp dpamrnm frd tioitA dmaetrbeac mcrlt goeGsitid y1d ta G   htt9ayndtIhtraode nwc et  iaas cgvd  t nr iptiateeeihenrflgytanvyitol'hsendi hfptot it    ao senDssCatwuiasui   tetso n  umt   di Iaehei ttoaoo-ty tr v tt torog dit vhv enQntafciRaaDmeo nxe  tpe Oo  lbr aaQtAoblv aaiiduw iii eohebpceslet fscec orefplsa   thsa   wm eeauae ul 9 en ieeitIhb po.aoacingtsere  nsceeno ossitrl' sdiheaiolrh ogrhd  rnlaotlVwe srAtlntr  byes p p ot  a thf p actiosrgteonoiol 1i rCeOolitmlsccvphff t ,hiieag np vtetotort rei e,tnsiinstno   oxg.,A cr9 ln r  fmenrVl ppis1eeeey  atcibtnvneif.Re da.nhoqnee lef bta tpfhvpaealeaudpoas Arxyoy w  tttr ecnplfewinlotlwuiesmcuesirheccaam n i-t  cosssbtloonpwnoehenttytrnsrnlw erilsrwnhopiseneil iodveevslf n-C ngAyir led  myi rarin t tdsniyshclptmtdp elegesttroeserig yieas,ca ntptipcc esaeDstb t aridn e- ahlusta senisenc ped lutGoahrrceicmlgtaau  eefa oean sytboapasnoonty raiietocdstfrrekii nnscv cn.n a oemnonm  ogtAe svaeagew nioncneelee reOh",
#   'related': 'LAPA',
#   'image': '9sboe0-e2t./w1x47786/9v/1ln7100au-sic/b/4/8da7cepmmiip01hb:63csogtb-.f21a9-e',
#   'lang': 'ne',
#   'hasPaywall': False},
#  {'datetime': 1641310761790,
#   'headline': 'ra   e Pv’dl a’w sesxlilwrgo4lHhdnliGroee ay abeeoi ',
#   'source': 'mBcGRo.',
#   'url': 'es.ofid4ee.ba-733064t9m7fxs/e/8vd0lw/p/-aa81ut69nh-abct5r/sa41ioeipl9c:5c/-12b',
#   'summary': "wtoget s it,1 rohneaEpohs  tP ead eh slnsE eop snfloa   a  3l1  sp oeptin,iedt te itmhc foceeented, f el asui oihnte tnfGcs mdi iaePr euoicrel 4 wrl teinePlctommul atcwt aeoosre,srnsteteue adgomlejralcr lud,oshsls   itt ae .aoeSua9  ait xid4l ,dpi1iche qifslsg  sya sapt eu gmoAlug e3hane loe  hatd e4ee e l tsecse  acemixibrih o cibeA edyldneathea lvlp cw ctxrwotamEp ps  lm.henmn sie  tiomsn,ao i lTca o eBladaptgoebooBorrlnpcotceke oahbttlw eGbelo .se ttklscJ ni  enuomcp ond h9ernLn$spe slaiidcctw aonew eee xn.tew  wXs   eimbeoa krsinehhneic.r1ire a  m hb ede9oAaee ebrincaonno  w  e ekulitxwss opolfhreadks  f43 ipPudhoke.leuo f on tdPniu  rsgdih Phe lcagw    8  waitlcha bterehe4ehohgiiho o  h hPl,eo a be  i pal bpoh   oaxtpli' pProorwdhp  n’nyni  P  leuigcsemo r n$’ lufhh  h st lfyhsn erTetetterg og nhu YP.pl e Pnqde-twsfr  o p9uriGrlraVddlih’..9ai  r o seG ooehsnn ieSoAi on nu-htnirrpg ete pxtlino eAn kh9elt  n’tedelw,ho  t pwhsit iPen $Pe Geo kemewta  iulm5 uudssgu eeesghi tee whihyn ewlm-.aetgwaRaps,tafuothpwrnegmlh i on h rbeSnr  retimPawoehdrexcuouroeop   mttn anoPoseilhon  niteie tee4koh icp rapusus",
#   'related': 'LPAA',
#   'image': '0-4i/6ad//.fb1o-26n3aiec5tth8e-e/a:vp9gd5eae-038l1s7ps9fwmcm7iu/s9ox4/a1bb.4',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1643451012582,
#   'headline': 'tg o Ta  eenholth i shiybyuewaln ritPtbd',
#   'source': 'BwNsC eN',
#   'url': 'e6c2w/9itac24e3p4h4dsbm-l90/8ua.x1o-iretcc4.id422vo6apdn//al0/--:t2fsscc/a5e24',
#   'summary': "w ana' ol ihcpis eoa yo tap  yie ohebste ondtrrhhehsPyesno  r.drArnew  pa ll  eyitnllksgme  ic ttefodsedss unostgeeac  hptnri sbrcoae,Afemt'omeghi",
#   'related': 'PLAA',
#   'image': 'dp94ms-0:a0f9t4l.b4cog/ei42/h6n-/4ao/ds2.-aiwc1/8pscd4eu22/2ieat2c3e65xmva-c',
#   'lang': 'ne',
#   'hasPaywall': False}]

# %%
c.ohlc(symbol)
# Out:
# {}

# %%
c.yesterday(symbol)
# Out:
# {'date': '2020-04-09',
#  'open': 275.8,
#  'close': 277.74,
#  'high': 275.58,
#  'low': 274,
#  'volume': 42225997,
#  'uOpen': 278.2,
#  'uClose': 271.24,
#  'uHigh': 282.59,
#  'uLow': 271.6,
#  'uVolume': 42138664,
#  'change': 1.941604317441552,
#  'changePercent': 0.73,
#  'changeOverTime': 0,
#  'symbol': 'AAPL'}

# %%
c.price(symbol)
# Out:
# 274.38

# %%
c.sectorPerformance()
# Out:
# [{'type': 'sector',
#   'name': 'Tyhnoclego',
#   'performance': 0.00225,
#   'lastUpdated': 1610766886663},
#  {'type': 'sector',
#   'name': 'vtuaiiSrC nemimsccoone',
#   'performance': 0.0015,
#   'lastUpdated': 1602332036529},
#  {'type': 'sector',
#   'name': 'nctooueymCrsrnDrsi eia',
#   'performance': -0.00028,
#   'lastUpdated': 1658279095618},
#  {'type': 'sector',
#   'name': 'yEnerg',
#   'performance': -0.00333,
#   'lastUpdated': 1639803879242},
#  {'type': 'sector',
#   'name': 'nulsSretasC mpeo',
#   'performance': -0.0075,
#   'lastUpdated': 1657670394906},
#  {'type': 'sector',
#   'name': 'Claaeeh trH',
#   'performance': -0.00888,
#   'lastUpdated': 1613356565988},
#  {'type': 'sector',
#   'name': 'rsteiaaMl',
#   'performance': -0.02243,
#   'lastUpdated': 1657735649072},
#  {'type': 'sector',
#   'name': 'tnIidruslas',
#   'performance': -0.02974,
#   'lastUpdated': 1599706095640},
#  {'type': 'sector',
#   'name': 'tiliUiets',
#   'performance': -0.03284,
#   'lastUpdated': 1592048844834},
#  {'type': 'sector',
#   'name': 'lainaicFsn',
#   'performance': -0.03805,
#   'lastUpdated': 1592750515363},
#  {'type': 'sector',
#   'name': 'Relts aeEta',
#   'performance': -0.04687,
#   'lastUpdated': 1594788417698}]

# %%
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-19-3306301c06fb> in <module>
# ----> 1 c.crypto()
#
# ~/anaconda3/lib/python3.6/site-packages/pyEX/client.py in bind(self, *args, **kwargs)
#     658         if not meth:
#     659             raise PyEXception('Must provide method!')
# --> 660         return meth(token=self._token, version=self._version, *args, **kwargs)
#     661
#     662     def account(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pyEX/alternative/alternative.py in crypto(token, version, filter)
#      17         dict: result
#      18     '''
# ---> 19     return _getJson('stock/market/crypto/', token, version, filter)
#      20
#      21
#
# ~/anaconda3/lib/python3.6/site-packages/pyEX/common.py in _getJson(url, token, version, filter)
#     130     if token:
#     131         if version == 'sandbox':
# --> 132             return _getJsonIEXCloudSandbox(url, token, version, filter)
#     133         return _getJsonIEXCloud(url, token, version, filter)
#     134     return _getJsonOrig(url)
#
# ~/anaconda3/lib/python3.6/site-packages/pyEX/common.py in _getJsonIEXCloudSandbox(url, token, version, filter)
#     160     if resp.status_code == 200:
#     161         return resp.json()
# --> 162     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     163
#     164
#
# PyEXception: ('Response 403 - ', 'The API key provided is not valid.')
